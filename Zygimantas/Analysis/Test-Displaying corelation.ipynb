# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from IPython.display import display, HTML

d = {'onerewrewre' : pd.Series([-1., 2., 3.], index=['a', 'b', 'c']),
     'two' : pd.Series([1., -2., -93., 4.], index=['a', 'b', 'c', 'd']),
    '3werewr' : pd.Series([1., 20., 3., 4.], index=['a', 'b', 'c', 'd']),
    '4werwe' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
    '5' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
    '6ewrew' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
    '7wer' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
    '8' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '9' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '10werew' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '1werwer1' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '1werwe2' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '13' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '1wrewre4' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '1wrerew5' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '16' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '1ewrrewewr7' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '18' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '1wrewre9' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '20' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '2wreewr1' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '22' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '23' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '24' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '25' : pd.Series([18., 12., -13., 4.], index=['a', 'b', 'c', 'd']),
     '26' : pd.Series([-12., 62., 3., 14.], index=['a', 'b', 'c', 'd'])}
df = pd.DataFrame(d)

# %%
types = df.dtypes
types
# Out:
# 10werew        float64
# 13             float64
# 16             float64
# 18             float64
# 1ewrrewewr7    float64
# 1werwe2        float64
# 1werwer1       float64
# 1wrerew5       float64
# 1wrewre4       float64
# 1wrewre9       float64
# 20             float64
# 22             float64
# 23             float64
# 24             float64
# 25             float64
# 26             float64
# 2wreewr1       float64
# 3werewr        float64
# 4werwe         float64
# 5              float64
# 6ewrew         float64
# 7wer           float64
# 8              float64
# 9              float64
# onerewrewre    float64
# two            float64
# dtype: object

# %%
df
# Out:
#    10werew    13    16    18  1ewrrewewr7  1werwe2  1werwer1  1wrerew5  \
# a     18.0  18.0  18.0  18.0         18.0     18.0      18.0      18.0
# b     12.0  12.0  12.0  12.0         12.0     12.0      12.0      12.0
# c    -13.0 -13.0 -13.0 -13.0        -13.0    -13.0     -13.0     -13.0
# d      4.0   4.0   4.0   4.0          4.0      4.0       4.0       4.0
#
#    1wrewre4  1wrewre9  ...   2wreewr1  3werewr  4werwe     5  6ewrew  7wer  \
# a      18.0      18.0  ...       18.0      1.0    18.0  18.0    18.0  18.0
# b      12.0      12.0  ...       12.0     20.0    12.0  12.0    12.0  12.0
# c     -13.0     -13.0  ...      -13.0      3.0   -13.0 -13.0   -13.0 -13.0
# d       4.0       4.0  ...        4.0      4.0     4.0   4.0     4.0   4.0
#
#       8     9  onerewrewre   two
# a  18.0  18.0         -1.0   1.0
# b  12.0  12.0          2.0  -2.0
# c -13.0 -13.0          3.0 -93.0
# d   4.0   4.0          NaN   4.0
#
# [4 rows x 26 columns]

# %%
corr = df.corr().mul(100).astype(int)
corr
# Out:
#              10werew   13   16   18  1ewrrewewr7  1werwe2  1werwer1  1wrerew5  \
# 10werew          100  100  100  100          100      100       100       100
# 13               100  100  100  100          100      100       100       100
# 16               100  100  100  100          100      100       100       100
# 18               100  100  100  100          100      100       100       100
# 1ewrrewewr7      100  100  100  100          100      100       100       100
# 1werwe2          100  100  100  100          100      100       100       100
# 1werwer1         100  100  100  100          100      100       100       100
# 1wrerew5         100  100  100  100          100      100       100       100
# 1wrewre4         100  100  100  100          100      100       100       100
# 1wrewre9         100  100  100  100          100      100       100       100
# 20               100  100  100  100          100      100       100       100
# 22               100  100  100  100          100      100       100       100
# 23               100  100  100  100          100      100       100       100
# 24               100  100  100  100          100      100       100       100
# 25               100  100  100  100          100      100       100       100
# 26                14   14   14   14           14       14        14        14
# 2wreewr1         100  100  100  100          100      100       100       100
# 3werewr           24   24   24   24           24       24        24        24
# 4werwe           100  100  100  100          100      100       100       100
# 5                100  100  100  100          100      100       100       100
# 6ewrew           100  100  100  100          100      100       100       100
# 7wer             100  100  100  100          100      100       100       100
# 8                100  100  100  100          100      100       100       100
# 9                100  100  100  100          100      100       100       100
# onerewrewre      -81  -81  -81  -81          -81      -81       -81       -81
# two               89   89   89   89           89       89        89        89
#
#              1wrewre4  1wrewre9 ...   2wreewr1  3werewr  4werwe    5  6ewrew  \
# 10werew           100       100 ...        100       24     100  100     100
# 13                100       100 ...        100       24     100  100     100
# 16                100       100 ...        100       24     100  100     100
# 18                100       100 ...        100       24     100  100     100
# 1ewrrewewr7       100       100 ...        100       24     100  100     100
# 1werwe2           100       100 ...        100       24     100  100     100
# 1werwer1          100       100 ...        100       24     100  100     100
# 1wrerew5          100       100 ...        100       24     100  100     100
# 1wrewre4          100       100 ...        100       24     100  100     100
# 1wrewre9          100       100 ...        100       24     100  100     100
# 20                100       100 ...        100       24     100  100     100
# 22                100       100 ...        100       24     100  100     100
# 23                100       100 ...        100       24     100  100     100
# 24                100       100 ...        100       24     100  100     100
# 25                100       100 ...        100       24     100  100     100
# 26                 14        14 ...         14       98      14   14      14
# 2wreewr1          100       100 ...        100       24     100  100     100
# 3werewr            24        24 ...         24      100      24   24      24
# 4werwe            100       100 ...        100       24     100  100     100
# 5                 100       100 ...        100       24     100  100     100
# 6ewrew            100       100 ...        100       24     100  100     100
# 7wer              100       100 ...        100       24     100  100     100
# 8                 100       100 ...        100       24     100  100     100
# 9                 100       100 ...        100       24     100  100     100
# onerewrewre       -81       -81 ...        -81       36     -81  -81     -81
# two                89        89 ...         89       26      89   89      89
#
#              7wer    8    9  onerewrewre  two
# 10werew       100  100  100          -81   89
# 13            100  100  100          -81   89
# 16            100  100  100          -81   89
# 18            100  100  100          -81   89
# 1ewrrewewr7   100  100  100          -81   89
# 1werwe2       100  100  100          -81   89
# 1werwer1      100  100  100          -81   89
# 1wrerew5      100  100  100          -81   89
# 1wrewre4      100  100  100          -81   89
# 1wrewre9      100  100  100          -81   89
# 20            100  100  100          -81   89
# 22            100  100  100          -81   89
# 23            100  100  100          -81   89
# 24            100  100  100          -81   89
# 25            100  100  100          -81   89
# 26             14   14   14           45   25
# 2wreewr1      100  100  100          -81   89
# 3werewr        24   24   24           36   26
# 4werwe        100  100  100          -81   89
# 5             100  100  100          -81   89
# 6ewrew        100  100  100          -81   89
# 7wer          100  100  100          -81   89
# 8             100  100  100          -81   89
# 9             100  100  100          -81   89
# onerewrewre   -81  -81  -81          100  -71
# two            89   89   89          -71  100
#
# [26 rows x 26 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cg = sns.clustermap(figsize=(15,15),data=corr, annot=True, fmt='d', cmap='Reds', linewidths=.5)
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
plt
sns.plt.show()
