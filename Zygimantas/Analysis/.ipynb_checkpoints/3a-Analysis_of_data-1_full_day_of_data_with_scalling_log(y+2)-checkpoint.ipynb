# %% [markdown]
# # Analysis of most promenant algorithm
#
# In this notebook I will document the search for best algrothm to analyse TransferMonitoring data

# %% [markdown]
# ## Loading and initial setup

# %%
# %matplotlib inline
# Here i keep prepared csv file for ML
f = open('/home/zygis/mnt/out.csv')

import numpy as np
import pandas as pd
from pandas import read_csv
from IPython.display import display, HTML

# in order to display of dataframe
pd.set_option('display.max_columns', 60)
pd.set_option('display.max_rows', 30)

dataframe = read_csv(f).astype(np.float32)

# to see struckture of data, uncoment
# dataframe 

# save headers to seperate list
original_headers = list(dataframe.columns.values)

# to see list of headeers, uncoment
print(len(original_headers))
display(original_headers)
# Out:
# 53
# ['block_size',
#  'buf_size',
#  'channel_type',
#  'chk_timeout',
#  'dest_srm_v',
#  'dst_hostname',
#  'dst_site_name',
#  'dst_url',
#  'endpnt',
#  'f_size',
#  'file_metadata',
#  'file_metadata|activity',
#  'file_metadata|adler32',
#  'file_metadata|dest_rse_id',
#  'file_metadata|dst_rse',
#  'file_metadata|dst_type',
#  'file_metadata|filesize',
#  'file_metadata|md5',
#  'file_metadata|name',
#  'file_metadata|previous_attempt_id',
#  'file_metadata|request_id',
#  'file_metadata|scope',
#  'file_metadata|src_rse',
#  'file_metadata|src_type',
#  'job_m_replica',
#  'job_metadata',
#  'job_metadata|issuer',
#  'job_metadata|multi_sources',
#  'job_state',
#  'nstreams',
#  'retry',
#  'retry_max',
#  'src_hostname',
#  'src_site_name',
#  'src_srm_v',
#  'src_url',
#  'srm_space_token_dst',
#  'srm_space_token_src',
#  't_channel',
#  't_error_code',
#  't_timeout',
#  'tcp_buf_size',
#  'time_srm_fin_st',
#  'time_srm_prep_st',
#  'timestamp_checksum_dest_st',
#  'timestamp_chk_src_st',
#  'tr_timestamp_complete',
#  'tr_timestamp_start',
#  'user_dn',
#  'vo',
#  'tr_id',
#  'timestamp_tr_st',
#  'timestamp_tr_dlt']

# %% [markdown]
# # Preprocesing step
# ## Check if data is missing any value

# %%
dataframe.isnull().any()
# Out:
# block_size                    False
# buf_size                      False
# channel_type                  False
# chk_timeout                   False
# dest_srm_v                    False
# dst_hostname                  False
# dst_site_name                 False
# dst_url                       False
# endpnt                        False
# f_size                        False
# file_metadata                 False
# file_metadata|activity        False
# file_metadata|adler32         False
# file_metadata|dest_rse_id     False
# file_metadata|dst_rse         False
#                               ...
# t_channel                     False
# t_error_code                  False
# t_timeout                     False
# tcp_buf_size                  False
# time_srm_fin_st               False
# time_srm_prep_st              False
# timestamp_checksum_dest_st    False
# timestamp_chk_src_st          False
# tr_timestamp_complete         False
# tr_timestamp_start            False
# user_dn                       False
# vo                            False
# tr_id                         False
# timestamp_tr_st               False
# timestamp_tr_dlt              False
# dtype: bool

# %%
# -- uncoment to see data types
# types = dataframe.dtypes
# types

# %%
try: 
    # if true, dataframe contains infinite numbers(bad)     
    print(np.all(np.isfinite(dataframe)))
except:
    pass
# Out:
# True

# %%
try:    
    print(np.any(np.isnan(dataframe)))
except:
    pass
# Out:
# False

# %% [markdown]
# Selecting importat features
# ---------
#
# Since our datasets is quit big, we should reduce the values inorder to save resources and increase computational speed.

# %% [markdown]
# First we drop out unvanted columns that for sure will not tell anything important for us.

# %%
dataframe = dataframe.drop(['tr_id','tr_timestamp_start','t_error_code'], axis=1)

# a=list(dataframe.columns.values)

# %% [markdown]
# Now we pop out our target column, we will use it for later.

# %%
# from dataframe pop target column and transform to ndarray
target=dataframe.pop('timestamp_tr_dlt')

# %% [markdown]
# As an end result we will process this kind of matrix.

# %%
prepared_headers = list(dataframe.columns.values)

# %% [markdown]
# dataframe itself

# %%
from sklearn import preprocessing
dataframe
# Out:
#         block_size  buf_size  channel_type  chk_timeout  dest_srm_v  \
# 0              0.0       0.0     88.301003          0.0   87.146263
# 1              0.0       0.0     88.301003          0.0   87.146263
# 2              0.0       0.0     88.301003          0.0   87.146263
# 3              0.0       0.0     88.301003       1800.0   87.146263
# 4              0.0       0.0     88.301003       1800.0   87.146263
# 5              0.0       0.0     88.301003       1800.0   87.146263
# 6              0.0       0.0     88.301003       1800.0   87.146263
# 7              0.0       0.0     88.301003       1800.0   87.146263
# 8              0.0       0.0     88.301003       1800.0   87.146263
# 9              0.0       0.0     88.301003       1800.0   87.146263
# 10             0.0       0.0     88.301003       1800.0   87.146263
# 11             0.0       0.0     88.301003       1800.0   87.146263
# 12             0.0       0.0     88.301003       1800.0   87.146263
# 13             0.0       0.0     88.301003       1800.0   87.146263
# 14             0.0       0.0     88.301003          0.0   87.146263
# ...            ...       ...           ...          ...         ...
# 685499         0.0       0.0     88.301003          0.0   87.146263
# 685500         0.0       0.0     88.301003          0.0   87.146263
# 685501         0.0       0.0     88.301003          0.0   87.146263
# 685502         0.0       0.0     88.301003       1800.0   87.146263
# 685503         0.0       0.0     88.301003          0.0   87.146263
# 685504         0.0       0.0     88.301003          0.0   87.146263
# 685505         0.0       0.0     88.301003          0.0   87.146263
# 685506         0.0       0.0     88.301003          0.0   87.146263
# 685507         0.0       0.0     88.301003          0.0   87.146263
# 685508         0.0       0.0     88.301003          0.0   87.146263
# 685509         0.0       0.0     88.301003          0.0   87.146263
# 685510         0.0       0.0     88.301003       1800.0    0.000000
# 685511         0.0       0.0     88.301003       1800.0    0.000000
# 685512         0.0       0.0     88.301003          0.0   87.146263
# 685513         0.0       0.0     88.301003          0.0   87.146263
#
#         dst_hostname  dst_site_name    dst_url     endpnt        f_size  \
# 0          85.467171            0.0  87.859352  88.701981  2.127745e+09
# 1          88.026329            0.0  88.401627  88.701981  1.527680e+07
# 2          88.678413            0.0  87.502213  88.701981  2.666740e+09
# 3          87.771095            0.0  87.942703  86.832253  2.685586e+09
# 4          87.771095            0.0  86.337303  86.832253  2.999112e+09
# 5          88.303612            0.0  83.947197  88.678986  4.900000e+02
# 6          88.485664            0.0  85.674934  88.678986  4.107188e+09
# 7          88.485664            0.0  88.357704  88.678986  3.976307e+09
# 8          88.303612            0.0  86.443489  88.678986  4.900000e+02
# 9          88.485664            0.0  88.654030  88.678986  3.949724e+09
# 10         87.771095            0.0  87.418221  86.832253  2.688047e+09
# 11         88.707619            0.0  86.270355  88.678986  2.684355e+09
# 12         87.993652            0.0  87.193047  88.443825  1.048576e+06
# 13         87.892143            0.0  87.950920  88.443825  1.048576e+06
# 14         88.469917            0.0  86.567146  88.701981  7.713745e+06
# ...              ...            ...        ...        ...           ...
# 685499     88.469917            0.0  87.463219  88.701981  9.907060e+05
# 685500     87.857178            0.0  88.410271  88.701981  7.926800e+06
# 685501     87.857178            0.0  85.752159  88.701981  4.967448e+07
# 685502     88.054146            0.0  88.530869  88.443825  1.048576e+06
# 685503     87.939865            0.0  88.388977  88.701981  1.166998e+09
# 685504     88.469917            0.0  88.646149  88.701981  9.886290e+05
# 685505     88.469917            0.0  88.559219  88.701981  8.132530e+05
# 685506     87.857178            0.0  88.413078  88.701981  2.461311e+07
# 685507     88.469917            0.0  88.149635  88.701981  1.569552e+09
# 685508     88.469917            0.0  87.199852  88.701981  9.911810e+05
# 685509     87.760818            0.0  86.625206  88.701981  2.591725e+07
# 685510     87.453415            0.0  88.050301  88.678986  2.673041e+07
# 685511     87.453415            0.0  85.490059  88.678986  2.254475e+07
# 685512     87.760818            0.0  88.192627  88.701981  2.395177e+07
# 685513     87.243660            0.0  87.032593  88.701981  2.811935e+06
#
#         file_metadata  file_metadata|activity  file_metadata|adler32  \
# 0                 0.0               -1.000000              -1.000000
# 1                -1.0               88.283684              87.456703
# 2                -1.0               88.384468              88.599884
# 3                 0.0               -1.000000              -1.000000
# 4                 0.0               -1.000000              -1.000000
# 5                -1.0               87.834015              88.597610
# 6                -1.0               88.384468              86.513412
# 7                -1.0               88.384468              85.491241
# 8                -1.0               87.834015              88.087425
# 9                -1.0               88.384468              88.202805
# 10                0.0               -1.000000              -1.000000
# 11                0.0               -1.000000              -1.000000
# 12               -1.0               87.629364              87.967369
# 13               -1.0               87.629364              88.621300
# 14               -1.0               87.195358              87.553017
# ...               ...                     ...                    ...
# 685499           -1.0               88.283684              86.121292
# 685500           -1.0               87.195358              88.226746
# 685501           -1.0               88.283684              85.055420
# 685502           -1.0               87.629364              87.840706
# 685503            0.0               -1.000000              -1.000000
# 685504           -1.0               88.283684              87.624153
# 685505           -1.0               88.283684              86.920273
# 685506           -1.0               88.283684              88.519119
# 685507           -1.0               87.935211              87.332054
# 685508           -1.0               88.283684              87.748245
# 685509            0.0               -1.000000              -1.000000
# 685510           -1.0               88.283684              88.289627
# 685511           -1.0               88.283684              87.668533
# 685512            0.0               -1.000000              -1.000000
# 685513            0.0               -1.000000              -1.000000
#
#         file_metadata|dest_rse_id  file_metadata|dst_rse  \
# 0                       -1.000000              -1.000000
# 1                       86.558624              87.638855
# 2                       86.596008              87.110565
# 3                       -1.000000              -1.000000
# 4                       -1.000000              -1.000000
# 5                       88.207535              86.590256
# 6                       86.722740              86.687187
# 7                       86.722740              86.687187
# 8                       88.207535              86.590256
# 9                       86.722740              86.687187
# 10                      -1.000000              -1.000000
# 11                      -1.000000              -1.000000
# 12                      87.439453              88.563362
# 13                      87.508194              87.080551
# 14                      87.427193              88.496033
# ...                           ...                    ...
# 685499                  87.427193              88.496033
# 685500                  87.904297              88.215416
# 685501                  87.904297              88.215416
# 685502                  88.374283              87.590630
# 685503                  -1.000000              -1.000000
# 685504                  87.427193              88.496033
# 685505                  87.427193              88.496033
# 685506                  87.904297              88.215416
# 685507                  87.427193              88.496033
# 685508                  87.427193              88.496033
# 685509                  -1.000000              -1.000000
# 685510                  87.533508              87.476768
# 685511                  87.533508              87.476768
# 685512                  -1.000000              -1.000000
# 685513                  -1.000000              -1.000000
#
#         file_metadata|dst_type  file_metadata|filesize  file_metadata|md5  \
# 0                    -1.000000           -1.000000e+00               -1.0
# 1                    86.892502            1.527680e+07                0.0
# 2                    86.892502            2.666740e+09                0.0
# 3                    -1.000000           -1.000000e+00               -1.0
# 4                    -1.000000           -1.000000e+00               -1.0
# 5                    86.892502            4.900000e+02                0.0
# 6                    86.892502            4.107188e+09                0.0
# 7                    86.892502            3.976307e+09                0.0
# 8                    86.892502            4.900000e+02                0.0
# 9                    86.892502            3.949724e+09                0.0
# 10                   -1.000000           -1.000000e+00               -1.0
# 11                   -1.000000           -1.000000e+00               -1.0
# 12                   86.892502            1.048576e+06                0.0
# 13                   86.892502            1.048576e+06                0.0
# 14                   86.892502            7.713745e+06                0.0
# ...                        ...                     ...                ...
# 685499               86.892502            9.907060e+05                0.0
# 685500               86.892502            7.926800e+06                0.0
# 685501               86.892502            4.967448e+07                0.0
# 685502               86.892502            1.048576e+06                0.0
# 685503               -1.000000           -1.000000e+00               -1.0
# 685504               86.892502            9.886290e+05                0.0
# 685505               86.892502            8.132530e+05                0.0
# 685506               86.892502            2.461311e+07                0.0
# 685507               86.892502            1.569552e+09                0.0
# 685508               86.892502            9.911810e+05                0.0
# 685509               -1.000000           -1.000000e+00               -1.0
# 685510               86.892502            2.673041e+07                0.0
# 685511               86.892502            2.254475e+07                0.0
# 685512               -1.000000           -1.000000e+00               -1.0
# 685513               -1.000000           -1.000000e+00               -1.0
#
#         file_metadata|name  file_metadata|previous_attempt_id  \
# 0                -1.000000                               -1.0
# 1                87.224586                               -1.0
# 2                84.729355                               -1.0
# 3                -1.000000                               -1.0
# 4                -1.000000                               -1.0
# 5                87.775726                               -1.0
# 6                87.590813                               -1.0
# 7                84.671425                               -1.0
# 8                87.471115                               -1.0
# 9                88.018890                               -1.0
# 10               -1.000000                               -1.0
# 11               -1.000000                               -1.0
# 12               88.443947                               -1.0
# 13               87.138130                               -1.0
# 14               88.629272                               -1.0
# ...                    ...                                ...
# 685499           87.027702                               -1.0
# 685500           87.005096                               -1.0
# 685501           87.481384                               -1.0
# 685502           86.790428                               -1.0
# 685503           -1.000000                               -1.0
# 685504           87.400284                               -1.0
# 685505           88.525055                               -1.0
# 685506           88.037292                               -1.0
# 685507           85.524414                               -1.0
# 685508           87.981018                               -1.0
# 685509           -1.000000                               -1.0
# 685510           88.060715                               -1.0
# 685511           87.666985                               -1.0
# 685512           -1.000000                               -1.0
# 685513           -1.000000                               -1.0
#
#         file_metadata|request_id  file_metadata|scope  file_metadata|src_rse  \
# 0                      -1.000000            -1.000000              -1.000000
# 1                      86.983086            88.228394              87.507774
# 2                      88.408546            87.497787              88.416237
# 3                      -1.000000            -1.000000              -1.000000
r = dataframe.corr().fillna(0).mul(100).astype(int)
corr = dataframe.corr().fillna(0).mul(100).astype(int)
corr
# Out:
#                             block_size  buf_size  channel_type  chk_timeout  \
# block_size                           0         0             0            0
# buf_size                             0         0             0            0
# channel_type                         0         0             0            0
# chk_timeout                          0         0             0          100
# dest_srm_v                           0         0             0          -20
# dst_hostname                         0         0             0           23
# dst_site_name                        0         0             0            0
# dst_url                              0         0             0            0
# endpnt                               0         0             0          -36
# f_size                               0         0             0           17
# file_metadata                        0         0             0          -22
# file_metadata|activity               0         0             0           22
# file_metadata|adler32                0         0             0            1
# file_metadata|dest_rse_id            0         0             0           22
# file_metadata|dst_rse                0         0             0           22
# ...                                ...       ...           ...          ...
# src_srm_v                            0         0             0           20
# src_url                              0         0             0            0
# srm_space_token_dst                  0         0             0           24
# srm_space_token_src                  0         0             0            8
# t_channel                            0         0             0           -2
# t_timeout                            0         0             0           20
# tcp_buf_size                         0         0             0            0
# time_srm_fin_st                      0         0             0           31
# time_srm_prep_st                     0         0             0            0
# timestamp_checksum_dest_st           0         0             0           44
# timestamp_chk_src_st                 0         0             0           29
# tr_timestamp_complete                0         0             0          -16
# user_dn                              0         0             0          -18
# vo                                   0         0             0          -26
# timestamp_tr_st                      0         0             0           35
#
#                             dest_srm_v  dst_hostname  dst_site_name  dst_url  \
# block_size                           0             0              0        0
# buf_size                             0             0              0        0
# channel_type                         0             0              0        0
# chk_timeout                        -20            23              0        0
# dest_srm_v                         100             4              0        0
# dst_hostname                         4           100              0        0
# dst_site_name                        0             0              0        0
# dst_url                              0             0              0      100
# endpnt                              -9             0              0        0
# f_size                              -4             0              0        0
# file_metadata                        3           -42              0        0
# file_metadata|activity              -3            42              0        0
# file_metadata|adler32                0             2              0        0
# file_metadata|dest_rse_id           -2            42              0        0
# file_metadata|dst_rse               -3            42              0        0
# ...                                ...           ...            ...      ...
# src_srm_v                           -8            52              0        0
# src_url                              0             0              0        0
# srm_space_token_dst                 -1            43              0        0
# srm_space_token_src                  2             1              0        0
# t_channel                            2           -11              0        0
# t_timeout                           -8             0              0        0
# tcp_buf_size                         0             0              0        0
# time_srm_fin_st                     -8            -7              0        0
# time_srm_prep_st                    -1            -4              0        0
# timestamp_checksum_dest_st         -17            37              0        0
# timestamp_chk_src_st               -13            48              0        0
# tr_timestamp_complete               -5            -1              0        0
# user_dn                             19           -16              0        0
# vo                                   3           -58              0        0
# timestamp_tr_st                     -9           -10              0        0
#
#                             endpnt  f_size  file_metadata  \
# block_size                       0       0              0
# buf_size                         0       0              0
# channel_type                     0       0              0
# chk_timeout                    -36      17            -22
# dest_srm_v                      -9      -4              3
# dst_hostname                     0       0            -42
# dst_site_name                    0       0              0
# dst_url                          0       0              0
# endpnt                         100     -20            -35
# f_size                         -20     100             21
# file_metadata                  -35      21            100
# file_metadata|activity          35     -21            -99
# file_metadata|adler32            2      -1             -7
# file_metadata|dest_rse_id       35     -22            -99
# file_metadata|dst_rse           35     -21            -99
# ...                            ...     ...            ...
# src_srm_v                       -2       7            -27
# src_url                          0       0              0
# srm_space_token_dst             25     -22            -96
# srm_space_token_src            -46      -4             16
# t_channel                        4      -8              1
# t_timeout                      -23      93             21
# tcp_buf_size                     0       0              0
# time_srm_fin_st                -11       9              3
# time_srm_prep_st                -2      -1            -14
# timestamp_checksum_dest_st       8      -7            -66
# timestamp_chk_src_st            16     -18            -89
# tr_timestamp_complete           11      -3              2
# user_dn                         29     -18            -17
# vo                              44     -14              0
# timestamp_tr_st                -14      11              3
#
#                             file_metadata|activity  file_metadata|adler32  \
# block_size                                       0                      0
# buf_size                                         0                      0
# channel_type                                     0                      0
# chk_timeout                                     22                      1
# dest_srm_v                                      -3                      0
# dst_hostname                                    42                      2
# dst_site_name                                    0                      0
# dst_url                                          0                      0
# endpnt                                          35                      2
# f_size                                         -21                     -1
# file_metadata                                  -99                     -7
# file_metadata|activity                         100                      7
# file_metadata|adler32                            7                    100
# file_metadata|dest_rse_id                       99                      7
# file_metadata|dst_rse                           99                      7
# ...                                            ...                    ...
# src_srm_v                                       27                      1
# src_url                                          0                      0
# srm_space_token_dst                             96                      6
# srm_space_token_src                            -16                     -1
# t_channel                                       -1                      0
# t_timeout                                      -20                     -1
# tcp_buf_size                                     0                      0
# time_srm_fin_st                                 -3                      0
# time_srm_prep_st                                14                      1
# timestamp_checksum_dest_st                      66                      4
# timestamp_chk_src_st                            89                      6
# tr_timestamp_complete                           -2                      0
# user_dn                                         17                      1
# vo                                               0                      0
# timestamp_tr_st                                 -3                      0
#
#                             file_metadata|dest_rse_id  file_metadata|dst_rse  \
# block_size                                          0                      0
# buf_size                                            0                      0
# channel_type                                        0                      0
# chk_timeout                                        22                     22
# dest_srm_v                                         -2                     -3
# dst_hostname                                       42                     42
# dst_site_name                                       0                      0
# dst_url                                             0                      0
# endpnt                                             35                     35
# f_size                                            -22                    -21
# file_metadata                                     -99                    -99
# file_metadata|activity                             99                     99
# file_metadata|adler32                               7                      7
# file_metadata|dest_rse_id                         100                     99
# file_metadata|dst_rse                              99                    100
# ...                                               ...                    ...
# src_srm_v                                          27                     27
# src_url                                             0                      0
# srm_space_token_dst                                96                     96
# srm_space_token_src                               -16                    -16
# t_channel                                          -1                     -1
# t_timeout                                         -21                    -21
# tcp_buf_size                                        0                      0
# time_srm_fin_st                                    -3                     -3
# time_srm_prep_st                                   14                     14
# timestamp_checksum_dest_st                         66                     66
# timestamp_chk_src_st                               89                     89
# tr_timestamp_complete                              -2                     -2
# user_dn                                            17                     17
# vo                                                  0                      0
# timestamp_tr_st                                    -3                     -3
#
#                             file_metadata|dst_type  file_metadata|filesize  \
# block_size                                       0                       0
# buf_size                                         0                       0
# channel_type                                     0                       0
# chk_timeout                                     22                      12
# dest_srm_v                                      -3                      -1
# dst_hostname                                    42                       8
# dst_site_name                                    0                       0
# dst_url                                          0                       0
# endpnt                                          35                       4
# f_size                                         -21                      71
# file_metadata                                  -99                     -21
# file_metadata|activity                          99                      21
# file_metadata|adler32                            7                       1
# file_metadata|dest_rse_id                       99                      21
# file_metadata|dst_rse                           99                      21
# ...                                            ...                     ...
# src_srm_v                                       27                       4
# src_url                                          0                       0
# srm_space_token_dst                             96                      20
# srm_space_token_src                            -16                      -3
# t_channel                                       -1                      -4
# t_timeout                                      -21                      67
# tcp_buf_size                                     0                       0
# time_srm_fin_st                                 -3                       9
# time_srm_prep_st                                14                       2
# timestamp_checksum_dest_st                      66                      21
# timestamp_chk_src_st                            89                      19
# tr_timestamp_complete                           -2                       0
# user_dn                                         17                       3
# vo                                               0                       0
# timestamp_tr_st                                 -3                      10
#
#                             file_metadata|md5  file_metadata|name  \
# block_size                                  0                   0
# buf_size                                    0                   0
# channel_type                                0                   0
# chk_timeout                                22                  22
# dest_srm_v                                 -3                  -3
# dst_hostname                               42                  42
# dst_site_name                               0                   0
# dst_url                                     0                   0
# endpnt                                     35                  35
# f_size                                    -21                 -21
# file_metadata                            -100                 -99
# file_metadata|activity                     99                  99
# file_metadata|adler32                       7                   7
# file_metadata|dest_rse_id                  99                  99
# file_metadata|dst_rse                      99                  99
# ...                                       ...                 ...
# src_srm_v                                  27                  27
# src_url                                     0                   0
# srm_space_token_dst                        96                  96
# srm_space_token_src                       -16                 -16
# t_channel                                  -1                  -1
# t_timeout                                 -21                 -21
# tcp_buf_size                                0                   0
# time_srm_fin_st                            -3                  -3
# time_srm_prep_st                           14                  14
# timestamp_checksum_dest_st                 66                  66
# timestamp_chk_src_st                       89                  89
# tr_timestamp_complete                      -2                  -2
# user_dn                                    17                  17
# vo                                          0                   0
# timestamp_tr_st                            -3                  -3
#
#                             file_metadata|previous_attempt_id  \
# block_size                                                  0
# buf_size                                                    0
# channel_type                                                0
# chk_timeout                                               -27
# dest_srm_v                                                  8
# dst_hostname                                                9
# dst_site_name                                               0
# dst_url                                                     0
# endpnt                                                     11
# f_size                                                    -13
# file_metadata                                             -20
# file_metadata|activity                                     19
# file_metadata|adler32                                       1
# file_metadata|dest_rse_id                                  20
# file_metadata|dst_rse                                      19
# ...                                                       ...
# src_srm_v                                                   9
# src_url                                                     0
# srm_space_token_dst                                        19
# srm_space_token_src                                        -3
# t_channel                                                   3
# t_timeout                                                 -13
# tcp_buf_size                                                0
# time_srm_fin_st                                           -69
# time_srm_prep_st                                            0
# timestamp_checksum_dest_st                                -37
# timestamp_chk_src_st                                       17
# tr_timestamp_complete                                       8
# user_dn                                                     3
# vo                                                          0
# timestamp_tr_st                                           -69
#
#                             file_metadata|request_id  file_metadata|scope  \
# block_size                                         0                    0
# buf_size                                           0                    0
# channel_type                                       0                    0
# chk_timeout                                       22                   22
# dest_srm_v                                        -3                   -3
# dst_hostname                                      42                   42
# dst_site_name                                      0                    0
# dst_url                                            0                    0
# endpnt                                            35                   35
# f_size                                           -21                  -22
# file_metadata                                    -99                  -99
# file_metadata|activity                            99                   99
# file_metadata|adler32                              7                    7
# file_metadata|dest_rse_id                         99                   99
# file_metadata|dst_rse                             99                   99
# ...                                              ...                  ...
# src_srm_v                                         27                   27
# src_url                                            0                    0
# srm_space_token_dst                               96                   96
# srm_space_token_src                              -16                  -16
# t_channel                                         -1                   -1
# t_timeout                                        -21                  -21
# tcp_buf_size                                       0                    0
# time_srm_fin_st                                   -3                   -3
# time_srm_prep_st                                  14                   14
# timestamp_checksum_dest_st                        66                   66
# timestamp_chk_src_st                              89                   89
# tr_timestamp_complete                             -2                   -2
# user_dn                                           17                   17
# vo                                                 0                    0
# timestamp_tr_st                                   -3                   -3
#
#                             file_metadata|src_rse  file_metadata|src_type  \
# block_size                                      0                       0
# buf_size                                        0                       0
# channel_type                                    0                       0
# chk_timeout                                    22                      22
# dest_srm_v                                     -2                      -3
# dst_hostname                                   42                      42
# dst_site_name                                   0                       0
# dst_url                                         0                       0
# endpnt                                         35                      35
# f_size                                        -21                     -21
# file_metadata                                 -99                     -99
# file_metadata|activity                         99                      99
# file_metadata|adler32                           7                       7
# file_metadata|dest_rse_id                      99                      99
# file_metadata|dst_rse                          99                      99
# ...                                           ...                     ...
# src_srm_v                                      27                      27
# src_url                                         0                       0
# srm_space_token_dst                            96                      96
# srm_space_token_src                           -16                     -16
# t_channel                                      -1                      -1
# t_timeout                                     -21                     -21
# tcp_buf_size                                    0                       0
# time_srm_fin_st                                -3                      -3
# time_srm_prep_st                               14                      14
# timestamp_checksum_dest_st                     66                      66
# timestamp_chk_src_st                           89                      89
# tr_timestamp_complete                          -2                      -2
# user_dn                                        17                      17
# vo                                              0                       0
# timestamp_tr_st                                -3                      -3
#
#                             job_m_replica  job_metadata  job_metadata|issuer  \
# block_size                              0             0                    0
# buf_size                                0             0                    0
# channel_type                            0             0                    0
# chk_timeout                            -8             0                    0
# dest_srm_v                              0            -1                    1
# dst_hostname                           10           -49                   49
# dst_site_name                           0             0                    0
# dst_url                                 0             0                    0
# endpnt                                 16           -49                   49
# f_size                                 11            32                  -32
# file_metadata                         -37            79                  -79
# file_metadata|activity                 37           -79                   79
# file_metadata|adler32                   2            -5                    5
# file_metadata|dest_rse_id              37           -79                   79
# file_metadata|dst_rse                  37           -79                   79
# ...                                   ...           ...                  ...
# src_srm_v                              13           -36                   36
# src_url                                 0             0                    0
# srm_space_token_dst                    36           -73                   74
# srm_space_token_src                    -6            20                  -20
# t_channel                              -3             1                   -1
# t_timeout                              10            31                  -31
# tcp_buf_size                            0             0                    0
# time_srm_fin_st                       -37             9                   -9
# time_srm_prep_st                        6           -12                   12
# timestamp_checksum_dest_st             -1           -46                   46
# timestamp_chk_src_st                   34           -63                   63
# tr_timestamp_complete                   1            -4                    4
# user_dn                                 6           -22                   22
# vo                                      0            12                  -12
# timestamp_tr_st                       -38             9                   -9
#
#                             job_metadata|multi_sources  job_state  nstreams  \
# block_size                                           0          0         0
# buf_size                                             0          0         0
# channel_type                                         0          0         0
# chk_timeout                                          8          4        39
# dest_srm_v                                          -1          0       -19
# dst_hostname                                        31         -7        -3
# dst_site_name                                        0          0         0
# dst_url                                              0          0         0
# endpnt                                              31        -12       -36
# f_size                                              -6        -10        58
# file_metadata                                      -83         29        27
# file_metadata|activity                              83        -29       -27
# file_metadata|adler32                                5         -2        -2
# file_metadata|dest_rse_id                           83        -29       -28
# file_metadata|dst_rse                               83        -29       -27
# ...                                                ...        ...       ...
# src_srm_v                                           25        -11         5
# src_url                                              0          0         0
# srm_space_token_dst                                 80        -28       -27
# srm_space_token_src                                -13          4         2
# t_channel                                           -2          6        -9
# t_timeout                                           -6         -9        64
# tcp_buf_size                                         0          0         0
# time_srm_fin_st                                    -24         26        16
# time_srm_prep_st                                    12         -5         9
# timestamp_checksum_dest_st                          39          0        -9
# timestamp_chk_src_st                                74        -26       -20
# tr_timestamp_complete                                0          0        -6
# user_dn                                             14         -5       -34
# vo                                                   0          0       -18
# timestamp_tr_st                                    -25         26        17
#
#                             retry  retry_max  src_hostname  src_site_name  \
# block_size                      0          0             0              0
# buf_size                        0          0             0              0
# channel_type                    0          0             0              0
# chk_timeout                     0          0             6              0
# dest_srm_v                      0          0            -5              0
# dst_hostname                    0          0             3              0
# dst_site_name                   0          0             0              0
# dst_url                         0          0             0              0
# endpnt                          0          0             0              0
# f_size                          0          3           -11              0
# file_metadata                   0          1           -18              0
# file_metadata|activity          0         -1            18              0
# file_metadata|adler32           0          0             1              0
# file_metadata|dest_rse_id       0         -1            18              0
# file_metadata|dst_rse           0         -1            18              0
# ...                           ...        ...           ...            ...
# src_srm_v                       0          0             6              0
# src_url                         0          0             0              0
# srm_space_token_dst             0          0            19              0
# srm_space_token_src             1          9             2              0
# t_channel                       0          0             1              0
# t_timeout                       0          3            -9              0
# tcp_buf_size                    0          0             0              0
# time_srm_fin_st                 0          0            -6              0
# time_srm_prep_st                0          0             0              0
# timestamp_checksum_dest_st      0          0            11              0
# timestamp_chk_src_st            0          0            17              0
# tr_timestamp_complete           0          0            -4              0
# user_dn                         0          1             2              0
# vo                              0          0             0              0
# timestamp_tr_st                 0          0            -5              0
#
#                             src_srm_v  src_url  srm_space_token_dst  \
# block_size                          0        0                    0
# buf_size                            0        0                    0
# channel_type                        0        0                    0
# chk_timeout                        20        0                   24
# dest_srm_v                         -8        0                   -1
# dst_hostname                       52        0                   43
# dst_site_name                       0        0                    0
# dst_url                             0        0                    0
# endpnt                             -2        0                   25
# f_size                              7        0                  -22
# file_metadata                     -27        0                  -96
# file_metadata|activity             27        0                   96
# file_metadata|adler32               1        0                    6
# file_metadata|dest_rse_id          27        0                   96
# file_metadata|dst_rse              27        0                   96
# ...                               ...      ...                  ...
# src_srm_v                         100        0                   29
# src_url                             0      100                    0
# srm_space_token_dst                29        0                  100
# srm_space_token_src                 3        0                   -6
# t_channel                           4        0                   -2
# t_timeout                           7        0                  -19
# tcp_buf_size                        0        0                    0
# time_srm_fin_st                    -9        0                   -2
# time_srm_prep_st                    1        0                   14
# timestamp_checksum_dest_st         21        0                   68
# timestamp_chk_src_st               31        0                   90
# tr_timestamp_complete              -1        0                   -2
# user_dn                            -8        0                   15
# vo                                -56        0                  -11
# timestamp_tr_st                    -7        0                   -2
#
#                             srm_space_token_src  t_channel  t_timeout  \
# block_size                                    0          0          0
# buf_size                                      0          0          0
# channel_type                                  0          0          0
# chk_timeout                                   8         -2         20
# dest_srm_v                                    2          2         -8
# dst_hostname                                  1        -11          0
# dst_site_name                                 0          0          0
# dst_url                                       0          0          0
# endpnt                                      -46          4        -23
# f_size                                       -4         -8         93
# file_metadata                                16          1         21
# file_metadata|activity                      -16         -1        -20
# file_metadata|adler32                        -1          0         -1
# file_metadata|dest_rse_id                   -16         -1        -21
# file_metadata|dst_rse                       -16         -1        -21
# ...                                         ...        ...        ...
# src_srm_v                                     3          4          7
# src_url                                       0          0          0
# srm_space_token_dst                          -6         -2        -19
# srm_space_token_src                         100         -1         -2
# t_channel                                    -1        100        -11
# t_timeout                                    -2        -11        100
# tcp_buf_size                                  0          0          0
# time_srm_fin_st                               1         -4         13
# time_srm_prep_st                              1          0         10
# timestamp_checksum_dest_st                    5         -4         -5
# timestamp_chk_src_st                          5         -1        -16
# tr_timestamp_complete                         1          2         -3
# user_dn                                      -4          3        -23
# vo                                          -34         16        -20
# timestamp_tr_st                               3         -2         15
#
#                             tcp_buf_size  time_srm_fin_st  time_srm_prep_st  \
# block_size                             0                0                 0
# buf_size                               0                0                 0
# channel_type                           0                0                 0
# chk_timeout                            0               31                 0
# dest_srm_v                             0               -8                -1
# dst_hostname                           0               -7                -4
# dst_site_name                          0                0                 0
# dst_url                                0                0                 0
# endpnt                                 0              -11                -2
# f_size                                 0                9                -1
# file_metadata                          0                3               -14
# file_metadata|activity                 0               -3                14
# file_metadata|adler32                  0                0                 1
# file_metadata|dest_rse_id              0               -3                14
# file_metadata|dst_rse                  0               -3                14
# ...                                  ...              ...               ...
# src_srm_v                              0               -9                 1
# src_url                                0                0                 0
# srm_space_token_dst                    0               -2                14
# srm_space_token_src                    0                1                 1
# t_channel                              0               -4                 0
# t_timeout                              0               13                10
# tcp_buf_size                           0                0                 0
# time_srm_fin_st                        0              100                30
# time_srm_prep_st                       0               30               100
# timestamp_checksum_dest_st             0               55                16
# timestamp_chk_src_st                   0                1                21
# tr_timestamp_complete                  0              -10                -3
# user_dn                                0               -3               -11
# vo                                     0                4                 5
# timestamp_tr_st                        0               91                31
#
#                             timestamp_checksum_dest_st  timestamp_chk_src_st  \
# block_size                                           0                     0
# buf_size                                             0                     0
# channel_type                                         0                     0
# chk_timeout                                         44                    29
# dest_srm_v                                         -17                   -13
# dst_hostname                                        37                    48
# dst_site_name                                        0                     0
# dst_url                                              0                     0
# endpnt                                               8                    16
# f_size                                              -7                   -18
# file_metadata                                      -66                   -89
# file_metadata|activity                              66                    89
# file_metadata|adler32                                4                     6
# file_metadata|dest_rse_id                           66                    89
# file_metadata|dst_rse                               66                    89
# ...                                                ...                   ...
# src_srm_v                                           21                    31
# src_url                                              0                     0
# srm_space_token_dst                                 68                    90
# srm_space_token_src                                  5                     5
# t_channel                                           -4                    -1
# t_timeout                                           -5                   -16
# tcp_buf_size                                         0                     0
# time_srm_fin_st                                     55                     1
# time_srm_prep_st                                    16                    21
# timestamp_checksum_dest_st                         100                    76
# timestamp_chk_src_st                                76                   100
# tr_timestamp_complete                               -7                    -2
# user_dn                                              0                     2
# vo                                                 -14                   -17
# timestamp_tr_st                                     51                     1
#
#                             tr_timestamp_complete  user_dn   vo  \
# block_size                                      0        0    0
# buf_size                                        0        0    0
# channel_type                                    0        0    0
# chk_timeout                                   -16      -18  -26
# dest_srm_v                                     -5       19    3
# dst_hostname                                   -1      -16  -58
# dst_site_name                                   0        0    0
# dst_url                                         0        0    0
# endpnt                                         11       29   44
# f_size                                         -3      -18  -14
# file_metadata                                   2      -17    0
# file_metadata|activity                         -2       17    0
# file_metadata|adler32                           0        1    0
# file_metadata|dest_rse_id                      -2       17    0
# file_metadata|dst_rse                          -2       17    0
# ...                                           ...      ...  ...
# src_srm_v                                      -1       -8  -56
# src_url                                         0        0    0
# srm_space_token_dst                            -2       15  -11
# srm_space_token_src                             1       -4  -34
# t_channel                                       2        3   16
# t_timeout                                      -3      -23  -20
# tcp_buf_size                                    0        0    0
# time_srm_fin_st                               -10       -3    4
# time_srm_prep_st                               -3      -11    5
# timestamp_checksum_dest_st                     -7        0  -14
# timestamp_chk_src_st                           -2        2  -17
# tr_timestamp_complete                         100        2    2
# user_dn                                         2      100   24
# vo                                              2       24  100
# timestamp_tr_st                               -12       -3    2
#
#                             timestamp_tr_st
# block_size                                0
# buf_size                                  0
# channel_type                              0
# chk_timeout                              35
# dest_srm_v                               -9
# dst_hostname                            -10
# dst_site_name                             0
# dst_url                                   0
# endpnt                                  -14
# f_size                                   11
# file_metadata                             3
# file_metadata|activity                   -3
# file_metadata|adler32                     0
# file_metadata|dest_rse_id                -3
# file_metadata|dst_rse                    -3
# ...                                     ...
# src_srm_v                                -7
# src_url                                   0
# srm_space_token_dst                      -2
# srm_space_token_src                       3
# t_channel                                -2
# t_timeout                                15
# tcp_buf_size                              0
# time_srm_fin_st                          91
# time_srm_prep_st                         31
# timestamp_checksum_dest_st               51
# timestamp_chk_src_st                      1
# tr_timestamp_complete                   -12
# user_dn                                  -3
# vo                                        2
# timestamp_tr_st                         100
#
# [49 rows x 49 columns]

# %% [markdown]
# Lets see corelation matrix, ploted
# ------

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# corr = pd.DataFrame(X_noVariance).corr().fillna(0).mul(100).astype(int)


cg = sns.clustermap(figsize=(25,25),data=corr, annot=True, fmt='d', cmap='Reds', linewidths=.5)
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
plt
sns.plt.show()

# %% [markdown]
# Checking for colums with no variance
# ----

# %%
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold()
# X_noVariance = sel.fit_transform(dataframe) # get new array
X_noVariance = sel.fit(dataframe) # get treshold with support


support_list = sel.get_support()
a= [i for i,x in enumerate(support_list) if x == 0]
# atributes with 0 change
for i in a:
    print(i,original_headers[i])
# Out:
# 0 block_size
# 1 buf_size
# 2 channel_type
# 6 dst_site_name
# 33 src_site_name
# 40 t_timeout

# %% [markdown]
# ## Removing non variating values and correlation

# %% [markdown]
# Trying scaling on data
# ------

# %%
matrix_to_scale = dataframe.as_matrix()
# matrix_to_scale

# %%
# scale_X = preprocessing.scale(matrix_to_scale)
# # type(matrix_to_scale)
# scale_X

#  scale between [0;1]
min_max_scaler = preprocessing.MinMaxScaler()
X_scalled = min_max_scaler.fit_transform(matrix_to_scale)
X_scalled
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.93359184,
#          0.56125641,  0.99998426],
#        [ 0.        ,  0.        ,  0.        , ...,  0.91484737,
#          0.61546326,  0.99998444],
#        [ 0.        ,  0.        ,  0.        , ...,  0.91484737,
#          0.61546326,  0.99998438],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.91484737,
#          0.61546326,  1.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.90044212,
#          0.56125641,  1.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.96848297,
#          0.56125641,  0.99999994]], dtype=float32)

# %% [markdown]
# ML learning phase
# -----

# %% [markdown]
# Now we are preparing to matrixes to for analysis by transforming them to ndarray. One will be data, another one will be our target:

# %%
X = X_scalled
y = target.as_matrix()

# %% [markdown]
# Just to be sure, lets see how prepared data looks:

# %%
X
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.93359184,
#          0.56125641,  0.99998426],
#        [ 0.        ,  0.        ,  0.        , ...,  0.91484737,
#          0.61546326,  0.99998444],
#        [ 0.        ,  0.        ,  0.        , ...,  0.91484737,
#          0.61546326,  0.99998438],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.91484737,
#          0.61546326,  1.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.90044212,
#          0.56125641,  1.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.96848297,
#          0.56125641,  0.99999994]], dtype=float32)

# %%
y
# Out:
# array([  2.12183000e+05,   4.99000000e+03,   4.98730000e+04, ...,
#          8.24800000e+03,  -1.00000000e+00,   5.29930000e+04], dtype=float32)

# %%
import math
log_f= lambda x: math.log(x+2)
# log_f= lambda x: x

y = list(map(log_f,y))

# math.log(y+2)
# y

# %% [markdown]
# Now we will split data to train/test:

# %%
from sklearn.cross_validation import train_test_split 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=92)
len(X_train), len(X_test)
# Out:
# (459294, 226220)

# %% [markdown]
# Now we are prepared. Lets check some models and see results.
#
# Algortihm benchmark
# --------
# I used the following chart to select different regression algorithms for checking.

# %%
from IPython.display import Image
Image("http://scikit-learn.org/dev/_static/ml_map.png")

# %% [markdown]
# RandomForestRegressor
# ----------------
# First lets see how well RandomForestRegressor performs.

# %%
# Fit a Random Forest 
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

exp_2 = lambda x: math.exp(x) -2
y_test = list(map(exp_2,y_test))
y_pred = list(map(exp_2,y_pred))

output=[]
# comparing real values to predicted
for answ, pred in zip(y_test, y_pred): 
    output.append( (answ,pred) )
display(output[:100])
# Out:
# [(3406.0000000000023, 3724.512896912812),
#  (6107.999999999997, 6466.721677329819),
#  (121975.00000000009, 101152.59484569369),
#  (2102.9999999999995, 4314.253814899347),
#  (71452.99999999996, 55799.14132980364),
#  (3286.0000000000023, 3516.1544388128164),
#  (943.9999999999998, 1572.1495337196288),
#  (2565.0, 3022.3786512863353),
#  (204088.00000000015, 243680.0946762314),
#  (-1.0, -1.0),
#  (7654.000000000003, 8487.233817771646),
#  (140282.99999999994, 120318.64785711982),
#  (87693.00000000001, 144718.1825121128),
#  (25554.999999999978, 51032.47553078771),
#  (418282.00000000023, 592645.0436696791),
#  (13211.999999999993, 12702.92364134555),
#  (22015.000000000007, 6159.3412377168115),
#  (-1.0, -1.0),
#  (3892.000000000003, 4658.64002553123),
#  (-1.0, -1.0),
#  (3874.9999999999973, 4441.020559687922),
#  (-1.0, -1.0),
#  (3967.9999999999986, 3620.1876026830796),
#  (1324.0, 1881.5225729662297),
#  (10227.999999999998, 8794.307831131993),
#  (97482.99999999993, 153532.49911398723),
#  (2256268.000000001, 2135010.4509555),
#  (3057.9999999999977, 3163.699231606309),
#  (15178.999999999996, 20546.098662692035),
#  (167297.99999999985, 334137.0210168991),
#  (1909.0000000000002, 3368.0085084189272),
#  (3018.000000000001, 1745.5659147502377),
#  (1982.999999999999, 1933.9990345093377),
#  (-1.0, -1.0),
#  (2708.000000000001, 2442.475808775682),
#  (1598.9999999999995, 2028.700816608938),
#  (-1.0, -1.0),
#  (7648.999999999997, 9141.879344450654),
#  (143167.99999999988, 140479.74975891295),
#  (-1.0, -1.0),
#  (123719.99999999993, 159875.32713319195),
#  (14620.999999999987, 11108.367885297708),
#  (12490.0, 19429.351163260784),
#  (6039.999999999999, 6692.020160832774),
#  (4151.999999999999, 4539.542996876698),
#  (61476.00000000002, 88032.54893428415),
#  (3626.9999999999995, 4340.082175599474),
#  (-1.0, -1.0),
#  (2229.0, 1962.3806356144287),
#  (757.0000000000003, 674.227309833289),
#  (1552.9999999999998, 1932.7186887830312),
#  (16438.0, 14784.10154349798),
#  (3253.9999999999995, 2619.740737723759),
#  (11714.0, 12103.616338449141),
#  (-1.0, -1.0),
#  (11992.999999999995, 12270.675030247341),
#  (-1.0, -1.0),
#  (-1.0, -1.0),
#  (25740.999999999996, 44952.45928367845),
#  (8006.000000000001, 6403.08159118223),
#  (66178.0, 54521.077099882576),
#  (2025.999999999999, 1592.3934316489513),
#  (7280.000000000002, 7086.675572278437),
#  (-1.0, -1.0),
#  (-1.0, -1.0),
#  (3451.9999999999995, 3609.4131770497643),
#  (1479.9999999999995, 1565.149478072716),
#  (587.9999999999998, 574.4283006097571),
#  (8531.000000000005, 20391.652361300068),
#  (84158.99999999997, 49364.97603152137),
#  (3788.9999999999973, 4299.398527469488),
#  (5222.000000000001, 6733.798876188237),
#  (1443.0000000000005, 892.7961284662499),
#  (-1.0, -1.0),
#  (-1.0, -1.0),
#  (52937.999999999985, 41525.040765062025),
#  (4218.000000000002, 4703.5110704193075),
#  (-1.0, -1.0),
#  (1889.9999999999995, 2407.8792747898347),
#  (5819.000000000003, 8930.619248705847),
#  (10125.000000000004, 11003.684691546248),
#  (146712.00000000012, 259980.42181534882),
#  (1041.9999999999995, 1025.7341713533187),
#  (7409.999999999994, 8612.816396960849),
#  (1172096.0, 309277.51146077114),
#  (3203.999999999999, 2768.9306062756764),
#  (10682.000000000005, 8737.90118912961),
#  (-1.0, -1.0),
#  (50409.00000000004, 148562.44622890666),
#  (11718.999999999993, 8180.869620471315),
#  (9595.0, 11612.682768525812),
#  (6265.000000000002, 5625.64571598756),
#  (734569.9999999994, 593964.7423549393),
#  (4117.999999999998, 3700.2658211568655),
#  (41437.00000000004, 62721.02186974052),
#  (1647.9999999999998, 2388.8464085771775),
#  (123850.9999999999, 133638.9408271612),
#  (599.9999999999999, 1389.659829656538),
#  (13407.999999999989, 14699.665965659067),
#  (2347.0, 1690.515935835972)]

# %% [markdown]
# Error rates of this model:

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error 
print('MAE: {0}'.format(mean_absolute_error(y_test,y_pred)))
print ('RMSE: {0}'.format(mean_squared_error(y_test,y_pred)))
# Out:
# MAE: 27151.567616054814
# RMSE: 20042861703.63877

# %% [markdown]
# SGD Regressor
# -------------

# %%
# from sklearn import linear_model
# model = linear_model.SGDRegressor()
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)


# output=[]
# # comparing real values to predicted
# for answ, pred in zip(y_test, y_pred): 
#     output.append( (answ,pred) )
# display(output[:100])

# %%
# print('MAE: {0}'.format(mean_absolute_error(y_test,y_pred)))
# print ('RMSE: {0}'.format(mean_squared_error(y_test,y_pred)))

# %% [markdown]
# Cearly, not very good

# %% [markdown]
# ElasticNet
# -----------

# %%
# from sklearn import linear_model
# model = linear_model.Lasso(alpha=0.5)
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)

# output=[]
# # comparing real values to predicted
# for answ, pred in zip(y_test, y_pred): 
#     output.append( (answ,pred) )
# display(output[:100])

# %%
# print('MAE: {0}'.format(mean_absolute_error(y_test,y_pred)))
# print ('RMSE: {0}'.format(mean_squared_error(y_test,y_pred)))

# %% [markdown]
# Ridge
# -----

# %%
# from sklearn import linear_model
# model = linear_model.Ridge(alpha=1.0)
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)

# output=[]
# # comparing real values to predicted
# for answ, pred in zip(y_test, y_pred): 
#     output.append( (answ,pred) )
# display(output[:100])

# %%
# print('MAE: {0}'.format(mean_absolute_error(y_test,y_pred)))
# print ('RMSE: {0}'.format(mean_squared_error(y_test,y_pred)))

# %% [markdown]
# Conclusion
# ------
# So random forest is the only ML algorithm that give predictions not so far away.

# %% [markdown]
# Resources
# -------
# - http://stackoverflow.com/questions/11023411/how-to-import-csv-data-file-into-scikit-learn
# - http://pandas.pydata.org/
# - http://scikit-learn.org/stable/modules/scaling_strategies.html
# - http://stackoverflow.com/questions/9590114/importance-of-pca-or-svd-in-machine-learning
# - http://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_error.html
# - http://scikit-learn.org/stable/modules/feature_selection.html#variance-threshold
# - http://stackoverflow.com/questions/29298973/removing-features-with-low-variance-scikit-learn
