# %% [markdown]
# Analysis of most promenant algorithm
# -----
# In this notebook I will document the search for best algrothm to analyse TransferMonitoring data

# %%
# Here i keep prepared csv file for ML
f = open('../data/output/json_hashed.csv')

import numpy as np
from pandas import read_csv
from IPython.display import display, HTML

dataframe = read_csv(f).astype(np.float32)

# to see struckture of data, uncoment
# dataframe 

# save headers to seperate list
original_headers = list(dataframe.columns.values)

# to see list of headeers, uncoment
print(len(original_headers))
display(original_headers)
# Out:
# 55
# ['block_size',
#  'buf_size',
#  'channel_type',
#  'chk_timeout',
#  'dest_srm_v',
#  'dst_hostname',
#  'dst_site_name',
#  'dst_url',
#  'endpnt',
#  'f_size',
#  'file_metadata',
#  'file_metadata|activity',
#  'file_metadata|adler32',
#  'file_metadata|dest_rse_id',
#  'file_metadata|dst_rse',
#  'file_metadata|dst_type',
#  'file_metadata|filesize',
#  'file_metadata|md5',
#  'file_metadata|name',
#  'file_metadata|previous_attempt_id',
#  'file_metadata|request_id',
#  'file_metadata|request_type',
#  'file_metadata|scope',
#  'file_metadata|src_rse',
#  'file_metadata|src_rse_id',
#  'file_metadata|src_type',
#  'is_recoverable',
#  'job_m_replica',
#  'job_metadata',
#  'job_metadata|issuer',
#  'job_metadata|multi_sources',
#  'job_state',
#  'nstreams',
#  'retry',
#  'retry_max',
#  'src_hostname',
#  'src_site_name',
#  'src_srm_v',
#  'src_url',
#  'srm_space_token_dst',
#  'srm_space_token_src',
#  't_channel',
#  't_error_code',
#  't_timeout',
#  'tcp_buf_size',
#  'time_srm_fin_st',
#  'time_srm_prep_st',
#  'timestamp_checksum_dest_st',
#  'timestamp_chk_src_st',
#  'tr_timestamp_start',
#  'user_dn',
#  'vo',
#  'tr_id',
#  'timestamp_tr_st',
#  'timestamp_tr_dlt']

# %% [markdown]
# Check if data is missing any value
# -------------

# %%
dataframe.isnull().any()
# Out:
# block_size                           False
# buf_size                             False
# channel_type                         False
# chk_timeout                          False
# dest_srm_v                           False
# dst_hostname                         False
# dst_site_name                        False
# dst_url                              False
# endpnt                               False
# f_size                               False
# file_metadata                        False
# file_metadata|activity               False
# file_metadata|adler32                False
# file_metadata|dest_rse_id            False
# file_metadata|dst_rse                False
# file_metadata|dst_type               False
# file_metadata|filesize               False
# file_metadata|md5                    False
# file_metadata|name                   False
# file_metadata|previous_attempt_id    False
# file_metadata|request_id             False
# file_metadata|request_type           False
# file_metadata|scope                  False
# file_metadata|src_rse                False
# file_metadata|src_rse_id             False
# file_metadata|src_type               False
# is_recoverable                       False
# job_m_replica                        False
# job_metadata                         False
# job_metadata|issuer                  False
# job_metadata|multi_sources           False
# job_state                            False
# nstreams                             False
# retry                                False
# retry_max                            False
# src_hostname                         False
# src_site_name                        False
# src_srm_v                            False
# src_url                              False
# srm_space_token_dst                  False
# srm_space_token_src                  False
# t_channel                            False
# t_error_code                         False
# t_timeout                            False
# tcp_buf_size                         False
# time_srm_fin_st                      False
# time_srm_prep_st                     False
# timestamp_checksum_dest_st           False
# timestamp_chk_src_st                 False
# tr_timestamp_start                   False
# user_dn                              False
# vo                                   False
# tr_id                                False
# timestamp_tr_st                      False
# timestamp_tr_dlt                     False
# dtype: bool

# %% [markdown]
# Selecting importat features
# ---------
#
# Since our datasets is quit big, we should reduce the values inorder to save resources and increase computational speed.

# %% [markdown]
# First we drop out unvanted columns that for sure will not tell anything important for us.

# %%
# dataframe.
try:
    dataframe = dataframe.drop(['tr_id','tr_timestamp_start','file_metadata|adler32'], axis=1)
except:
    pass
# a=list(dataframe.columns.values)

# %% [markdown]
# Now we pop out our target column, we will use it for later.

# %%
# from dataframe pop target column and transform to ndarray
target=dataframe.pop('timestamp_tr_dlt')

# %% [markdown]
# As an end result we will process this kind of matrix.

# %%
prepared_headers = list(dataframe.columns.values)
types = dataframe.dtypes

# %%
types
# Out:
# block_size                           float32
# buf_size                             float32
# channel_type                         float32
# chk_timeout                          float32
# dest_srm_v                           float32
# dst_hostname                         float32
# dst_site_name                        float32
# dst_url                              float32
# endpnt                               float32
# f_size                               float32
# file_metadata                        float32
# file_metadata|activity               float32
# file_metadata|adler32                float32
# file_metadata|dest_rse_id            float32
# file_metadata|dst_rse                float32
# file_metadata|dst_type               float32
# file_metadata|filesize               float32
# file_metadata|md5                    float32
# file_metadata|name                   float32
# file_metadata|previous_attempt_id    float32
# file_metadata|request_id             float32
# file_metadata|request_type           float32
# file_metadata|scope                  float32
# file_metadata|src_rse                float32
# file_metadata|src_rse_id             float32
# file_metadata|src_type               float32
# is_recoverable                       float32
# job_m_replica                        float32
# job_metadata                         float32
# job_metadata|issuer                  float32
# job_metadata|multi_sources           float32
# job_state                            float32
# nstreams                             float32
# retry                                float32
# retry_max                            float32
# src_hostname                         float32
# src_site_name                        float32
# src_srm_v                            float32
# src_url                              float32
# srm_space_token_dst                  float32
# srm_space_token_src                  float32
# t_channel                            float32
# t_error_code                         float32
# t_timeout                            float32
# tcp_buf_size                         float32
# time_srm_fin_st                      float32
# time_srm_prep_st                     float32
# timestamp_checksum_dest_st           float32
# timestamp_chk_src_st                 float32
# user_dn                              float32
# vo                                   float32
# timestamp_tr_st                      float32
# dtype: object

# %%
from sklearn import preprocessing
dataframe
# Out:
#       block_size  buf_size  channel_type  chk_timeout  dest_srm_v  \
# 0            0.0       0.0     88.301003       1800.0   87.146263
# 1            0.0       0.0     88.301003       1800.0   87.146263
# 2            0.0       0.0     88.301003       1800.0   87.146263
# 3            0.0       0.0     88.301003       1800.0   87.146263
# 4            0.0       0.0     88.301003       1800.0   87.146263
# 5            0.0       0.0     88.301003       1800.0   87.146263
# 6            0.0       0.0     88.301003       1800.0   87.146263
# 7            0.0       0.0     88.301003       1800.0   87.146263
# 8            0.0       0.0     88.301003          0.0   87.146263
# 9            0.0       0.0     88.301003       1800.0   87.146263
# 10           0.0       0.0     88.301003       1800.0   87.146263
# 11           0.0       0.0     88.301003       1800.0   87.146263
# 12           0.0       0.0     88.301003       1800.0   87.146263
# 13           0.0       0.0     88.301003       1800.0   87.146263
# 14           0.0       0.0     88.301003       1800.0   87.146263
# 15           0.0       0.0     88.301003       1800.0   87.146263
# 16           0.0       0.0     88.301003       1800.0   87.146263
# 17           0.0       0.0     88.301003       1800.0   87.146263
# 18           0.0       0.0     88.301003       1800.0   -2.000000
# 9990       ...                 -2.0     4539.0           0.0    -2.000000e+00
# 9991       ...                 -2.0      901.0           0.0     1.467151e+12
# 9992       ...                 -2.0      905.0           0.0     1.467151e+12
# 9993       ...                 -2.0    11997.0           0.0     1.467151e+12
# 9994       ...                 -2.0      901.0           0.0     1.467151e+12
# 9995       ...                 -2.0      903.0           0.0    -2.000000e+00
# 9996       ...                451.0     4918.0           0.0    -2.000000e+00
# 9997       ...                 -2.0      902.0           0.0     1.467151e+12
# 9998       ...                451.0     8969.0           0.0    -2.000000e+00
# 9999       ...                 -2.0     6205.0           0.0     1.467151e+12
#
#       time_srm_prep_st  timestamp_checksum_dest_st  timestamp_chk_src_st  \
# 0         1.467151e+12               -2.000000e+00          1.467151e+12
# 1         1.467151e+12                1.467151e+12          1.467151e+12
# 2         1.467151e+12               -2.000000e+00          1.467151e+12
# 3         1.467151e+12               -2.000000e+00         -2.000000e+00
# 4         1.467151e+12               -2.000000e+00         -2.000000e+00
# 5         1.467151e+12               -2.000000e+00         -2.000000e+00
# 6         1.467151e+12               -2.000000e+00         -2.000000e+00
# 7         1.467151e+12                1.467151e+12          1.467151e+12
# 8         1.467151e+12                1.467151e+12          1.467151e+12
# 9         1.467150e+12               -2.000000e+00         -2.000000e+00
# 10        1.467150e+12               -2.000000e+00         -2.000000e+00
# 11        1.467151e+12               -2.000000e+00         -2.000000e+00
# 12        1.467151e+12               -2.000000e+00          1.467151e+12
# 13        1.467151e+12               -2.000000e+00         -2.000000e+00
# 14        1.467151e+12               -2.000000e+00         -2.000000e+00
# 15        1.467151e+12               -2.000000e+00         -2.000000e+00
# 16        1.467150e+12               -2.000000e+00         -2.000000e+00
# 17        1.467150e+12                1.467151e+12          1.467150e+12
# 18        1.467151e+12                1.467151e+12          1.467151e+12
# 19        1.467151e+12               -2.000000e+00          1.467151e+12
# 20        1.467151e+12               -2.000000e+00          1.467151e+12
# 21        1.467151e+12               -2.000000e+00         -2.000000e+00
# 22        1.467151e+12               -2.000000e+00          1.467151e+12
# 23        1.467151e+12               -2.000000e+00          1.467151e+12
# 24        1.467151e+12               -2.000000e+00         -2.000000e+00
# 25        1.467151e+12               -2.000000e+00          1.467151e+12
# 26        1.467147e+12               -2.000000e+00         -2.000000e+00
# 27        1.467151e+12               -2.000000e+00          1.467151e+12
# 28        1.467151e+12               -2.000000e+00         -2.000000e+00
# 29        1.467151e+12               -2.000000e+00          1.467151e+12
# ...                ...                         ...                   ...
# 9970      1.467151e+12               -2.000000e+00         -2.000000e+00
# 9971      1.467151e+12               -2.000000e+00          1.467151e+12
# 9972      1.467149e+12                1.467151e+12          1.467149e+12
# 9973      1.467151e+12               -2.000000e+00          1.467151e+12
# 9974      1.467151e+12                1.467151e+12          1.467151e+12
# 9975      1.467151e+12               -2.000000e+00         -2.000000e+00
# 9976      1.467151e+12               -2.000000e+00          1.467151e+12
# 9977      1.467151e+12               -2.000000e+00          1.467151e+12
# 9978      1.467151e+12               -2.000000e+00          1.467151e+12
# 9979      1.467151e+12               -2.000000e+00          1.467151e+12
# 9980      1.467149e+12               -2.000000e+00          1.467149e+12
# 9981      1.467150e+12               -2.000000e+00         -2.000000e+00
# 9982      1.467151e+12               -2.000000e+00         -2.000000e+00
# 
# 9993  87.945396  87.703239     1.467151e+12
# 9994  88.406021  87.644180     1.467151e+12
# 9995  87.945396  87.703239    -2.000000e+00
# 9996  87.945396  87.703239     1.467151e+12
# 9997  88.406021  87.644180     1.467151e+12
# 9998  87.945396  87.703239     1.467143e+12
# 9999  87.945396  87.703239     1.467151e+12
#
# [10000 rows x 52 columns]

# %% [markdown]
# More checking on dataframe:

# %%
try:    
    print(np.any(np.isnan(dataframe)))
except:
    pass
# Out:
# False

# %%
try:    
    print(np.all(np.isfinite(dataframe)))
except:
    pass
np.isfinite?
# Out:
# False

# %%
# corr = dataframe.corr().fillna(0).mul(100).astype(int)
corr = dataframe.corr().fillna(0).mul(100).astype(int)
corr
# Out:
#                                    block_size  buf_size  channel_type  \
# block_size                                  0         0             0
# buf_size                                    0       100             0
# channel_type                                0         0             0
# chk_timeout                                 0         0             0
# dest_srm_v                                  0         0             0
# dst_hostname                                0        -6             0
# dst_site_name                               0         0             0
# dst_url                                     0         0             0
# endpnt                                      0        -1             0
# f_size                                      0         5             0
# file_metadata                               0         3             0
# file_metadata|activity                      0         6             0
# file_metadata|adler32                       0         0             0
# file_metadata|dest_rse_id                   0         6             0
# file_metadata|dst_rse                       0         6             0
# file_metadata|dst_type                      0         6             0
# file_metadata|filesize                      0        -1             0
# file_metadata|md5                           0        -6             0
# file_metadata|name                          0         6             0
# file_metadata|previous_attempt_id           0         1             0
# file_metadata|request_id                    0         6             0
# file_metadata|request_type                  0         6             0
# file_metadata|scope                         0         6             0
# file_metadata|src_rse                       0         6             0
# file_metadata|src_rse_id                    0         6             0
# file_metadata|src_type                      0         6             0
# is_recoverable                              0         5             0
# job_m_replica                               0         6             0
# job_metadata                                0        14             0
# job_metadata|issuer                         0        15             0
# job_metadata|multi_sources                  0         7             0
# job_state                                   0        -5             0
# nstreams                                    0        16             0
# retry                                       0       -17             0
# retry_max                                   0        -3             0
# src_hostname                                0         0             0
# src_site_name                               0         0             0
# src_srm_v                                   0        -3             0
# src_url                                     0         0             0
# srm_space_token_dst                         0         4             0
# srm_space_token_src                         0        -4             0
# t_channel                                   0         1             0
# t_error_code                                0         1             0
# t_timeout                                   0        10             0
# tcp_buf_size                                0       100             0
# time_srm_fin_st                             0        14             0
# time_srm_prep_st                            0        98             0
# timestamp_checksum_dest_st                  0         7             0
# timestamp_chk_src_st                        0        14             0
# user_dn                                     0         1             0
# vo                                          0         6             0
# timestamp_tr_st                             0        16             0
#
#                                    chk_timeout  dest_srm_v  dst_hostname  \
# block_size                                   0           0             0
# buf_size                                     0           0            -6
# channel_type                                 0           0             0
# chk_timeout                                100         -12             0
# dest_srm_v                                 -12         100             4
# dst_hostname                                 0           4           100
# dst_site_name                                0           0             0
# dst_url                                     -1           0             1
# endpnt                                      54          -9            -1
# f_size                                      -6           4             0
# file_metadata                              -38         -16           -41
# file_metadata|activity                     -37         -15           -39
# file_metadata|adler32                        0           0             1
# file_metadata|dest_rse_id                  -37         -16           -39
# file_metadata|dst_rse                      -37         -15           -39
# file_metadata|dst_type                     -37         -15           -39
# file_metadata|filesize                     -13           3             5
# file_metadata|md5                           37          15            39
# file_metadata|name                         -37         -15           -39
# file_metadata|previous_attempt_id          -28           8           -40
# file_metadata|request_id                   -37         -15           -39
# file_metadata|request_type                 -37         -15           -39
# file_metadata|scope                        -37         -15           -39
# file_metadata|src_rse                      -37         -15           -39
# file_metadata|src_rse_id                   -37         -15           -39
# file_metadata|src_type                     -37         -15           -39
# is_recoverable                             -39         -17             8
# job_m_replica                              -55           4             2
# job_metadata                                -5          -1            -6
# job_metadata|issuer                         -4          -1            -4
# job_metadata|multi_sources                 -53          -7           -22
# job_state                                   46          -3            -1
# nstreams                                    -4           4            -2
# retry                                        1           0             0
# retry_max                                    5           2            10
# src_hostname                                -9          -2             1
# src_site_name                                0           0             0
# src_srm_v                                  -10          -6             6
# src_url                                      0           0             0
# srm_space_token_dst                        -36         -14           -36
# srm_space_token_src                          4           2             7
# t_channel                                    0           0            -1
# t_error_code                                -4          -7            -3
# t_timeout                                   -5           4            -2
# tcp_buf_size                                 0           0            -6
# time_srm_fin_st                             23         -12            42
# time_srm_prep_st                            -1           2            -6
# timestamp_checksum_dest_st                  -7         -30            10
# timestamp_chk_src_st                       -36         -16           -37
# user_dn                                      4           0            11
# vo                                         -18          -7           -38
# timestamp_tr_st                             23         -15            40
#
#                                    dst_site_name  dst_url  endpnt  f_size  \
# block_size                                     0        0       0       0
# buf_size                                       0        0      -1       5
# channel_type                                   0        0       0       0
# chk_timeout                                    0       -1      54      -6
# dest_srm_v                                     0        0      -9       4
# dst_hostname                                   0        1      -1       0
# dst_site_name                                  0        0       0       0
# dst_url                                        0      100       0       1
# endpnt                                         0        0     100     -24
# f_size                                         0        1     -24     100
# file_metadata                                  0        0     -20      15
# file_metadata|activity                         0        0     -13       2
# file_metadata|adler32                          0        0       0       0
# file_metadata|dest_rse_id                      0        0     -14       2
# file_metadata|dst_rse                          0        0     -13       1
# file_metadata|dst_type                         0        0     -13       1
# file_metadata|filesize                         0        1      -7      65
# file_metadata|md5                              0        0      13      -1
# file_metadata|name                             0        0     -13       1
# file_metadata|previous_attempt_id              0       -1     -11     -15
# file_metadata|request_id                       0        0     -13       1
# file_metadata|request_type                     0        0     -13       1
# file_metadata|scope                            0        0     -13       1
# file_metadata|src_rse                          0        0     -13       1
# file_metadata|src_rse_id                       0        0     -13       1
# file_metadata|src_type                         0        0     -13       1
# is_recoverable                                 0        1      13       0
# job_m_replica                                  0        0     -36      -4
# job_metadata                                   0       -1      53     -35
# job_metadata|issuer                            0       -1      43     -44
# job_metadata|multi_sources                     0        0     -28      -1
# job_state                                      0        0      30       4
# nstreams                                       0        1     -21      87
# retry                                          0        0     -11       0
# retry_max                                      0        0     -52      -3
# src_hostname                                   0        0      -8       1
# src_site_name                                  0        0       0       0
# src_srm_v                                      0        0       2     -24
# src_url                                        0        0       0       0
# srm_space_token_dst                            0        0     -24       2
# srm_space_token_src                            0        0     -42      -2
# t_channel                                      0        0       5      -5
# t_error_code                                   0        0      -1       2
# t_timeout                                      0        1     -22      94
# tcp_buf_size                                   0        0      -1       5
# time_srm_fin_st                                0        1      10      10
# time_srm_prep_st                               0        0      -1       4
# timestamp_checksum_dest_st                     0        0     -14      24
# timestamp_chk_src_st                           0        0     -24       4
# user_dn                                        0        1       4       7
# vo                                             0        0      27       0
# timestamp_tr_st                                0        2       5      21
#
#                                         ...         t_error_code  t_timeout  \
# block_size                              ...                    0          0
# buf_size                                ...                    1         10
# channel_type                            ...                    0          0
# chk_timeout                             ...                   -4         -5
# dest_srm_v                              ...                   -7          4
# dst_hostname                            ...                   -3         -2
# dst_site_name                           ...                    0          0
# dst_url                                 ...                    0          1
# endpnt                                  ...                   -1        -22
# f_size                                  ...                    2         94
# file_metadata                           ...                   10         22
# file_metadata|activity                  ...                   10          9
# file_metadata|adler32                   ...                    0          0
# file_metadata|dest_rse_id               ...                   10          9
# file_metadata|dst_rse                   ...                   10          9
# file_metadata|dst_type                  ...                   10          9
# file_metadata|filesize                  ...                    5         67
# file_metadata|md5                       ...                  -10         -9
# file_metadata|name                      ...                   10          9
# file_metadata|previous_attempt_id       ...                   12        -18
# file_metadata|request_id                ...                   10          9
# file_metadata|request_type              ...                   10          9
# file_metadata|scope                     ...                   10          9
# file_metadata|src_rse                   ...                   10          9
# file_metadata|src_rse_id                ...                   10          9
# file_metadata|src_type                  ...                   10          9
# is_recoverable                          ...                   13          8
# job_m_replica                           ...                    4          0
# job_metadata                            ...                    3        -33
# job_metadata|issuer                     ...                    3        -42
# job_metadata|multi_sources              ...                    9          5
# job_state                               ...                   -6          1
# nstreams                                ...                    8         96
# retry                                   ...                    0         -1
# retry_max                               ...                   -1         -5
# src_hostname                            ...                   -3          1
# src_site_name                           ...                    0          0
# src_srm_v                               ...                  -21        -25
# src_url                                 ...                    0         -1
# srm_space_token_dst                     ...                   10          9
# srm_space_token_src                     ...                   -1         -4
# t_channel                               ...                   -3         -5
# t_error_code                            ...                  100          6
# t_timeout                               ...                    6        100
# tcp_buf_size                            ...                    1         10
# time_srm_fin_st                         ...                  -24         15
# time_srm_prep_st                        ...                    2          9
# timestamp_checksum_dest_st              ...                  -12         35
# timestamp_chk_src_st                    ...                   10         12
# user_dn                                 ...                    0          2
# vo                                      ...                    5          6
# timestamp_tr_st                         ...                   13         27
#
#                                    tcp_buf_size  time_srm_fin_st  \
# block_size                                    0                0
# buf_size                                    100               14
# channel_type                                  0                0
# chk_timeout                                   0               23
# dest_srm_v                                    0              -12
# dst_hostname                                 -6               42
# dst_site_name                                 0                0
# dst_url                                       0                1
# endpnt                                       -1               10
# f_size                                        5               10
# file_metadata                                 3              -42
# file_metadata|activity                        6              -40
# file_metadata|adler32                         0                0
# file_metadata|dest_rse_id                     6              -40
# file_metadata|dst_rse                         6              -40
# file_metadata|dst_type                        6              -40
# file_metadata|filesize                       -1               14
# file_metadata|md5                            -6               40
# file_metadata|name                            6              -40
# file_metadata|previous_attempt_id             1              -70
# file_metadata|request_id                      6              -40
# file_metadata|request_type                    6              -40
# file_metadata|scope                           6              -40
# file_metadata|src_rse                         6              -40
# file_metadata|src_rse_id                      6              -40
# file_metadata|src_type                        6              -40
# is_recoverable                                5               11
# job_m_replica                                 6              -18
# job_metadata                                 14               -6
# job_metadata|issuer                          15               -5
# job_metadata|multi_sources                    7              -35
# job_state                                    -5               18
# nstreams                                     16               18
# retry                                       -17               -2
# retry_max                                    -3                7
# src_hostname                                  0               -5
# src_site_name                                 0                0
# src_srm_v                                    -3               -8
# src_url                                       0                0
# srm_space_token_dst                           4              -38
# srm_space_token_src                          -4                5
# t_channel                                     1               -6
# t_error_code                                  1              -24
# t_timeout                                    10               15
# tcp_buf_size                                100               14
# time_srm_fin_st                              14              100
# time_srm_prep_st                             98               14
# timestamp_checksum_dest_st                    7               50
# timestamp_chk_src_st                         14              -36
# user_dn                                       1               11
# vo                                            6              -19
# timestamp_tr_st                              16               89
#
#                                    time_srm_prep_st  \
# block_size                                        0
# buf_size                                         98
# channel_type                                      0
# chk_timeout                                      -1
# dest_srm_v                                        2
# dst_hostname                                     -6
# dst_site_name                                     0
# dst_url                                           0
# endpnt                                           -1
# f_size                                            4
# file_metadata                                     2
# file_metadata|activity                            6
# file_metadata|adler32                             0
# file_metadata|dest_rse_id                         6
# file_metadata|dst_rse                             6
# file_metadata|dst_type                            6
# file_metadata|filesize                           -2
# file_metadata|md5                                -6
# file_metadata|name                                6
# file_metadata|previous_attempt_id                 1
# file_metadata|request_id                          6
# file_metadata|request_type                        6
# file_metadata|scope                               6
# file_metadata|src_rse                             6
# file_metadata|src_rse_id                          6
# file_metadata|src_type                            6
# is_recoverable                                    5
# job_m_replica                                     6
# job_metadata                                     14
# job_metadata|issuer                              15
# job_metadata|multi_sources                        7
# job_state                                        -5
# nstreams                                         15
# retry                                           -16
# retry_max                                        -3
# src_hostname                                      0
# src_site_name                                     0
# src_srm_v                                        -2
# src_url                                           0
# srm_space_token_dst                               4
# srm_space_token_src                              -4
# t_channel                                         1
# t_error_code                                      2
# t_timeout                                         9
# tcp_buf_size                                     98
# time_srm_fin_st                                  14
# time_srm_prep_st                                100
# timestamp_checksum_dest_st                        6
# timestamp_chk_src_st                             14
# user_dn                                           1
# vo                                                5
# timestamp_tr_st                                  15
#
#                                    timestamp_checksum_dest_st  \
# block_size                                                  0
# buf_size                                                    7
# channel_type                                                0
# chk_timeout                                                -7
# dest_srm_v                                                -30
# dst_hostname                                               10
# dst_site_name                                               0
# dst_url                                                     0
# endpnt                                                    -14
# f_size                                                     24
# file_metadata                                              43
# file_metadata|activity                                     43
# file_metadata|adler32                                       1
# file_metadata|dest_rse_id                                  44
# file_metadata|dst_rse                                      43
# file_metadata|dst_type                                     43
# file_metadata|filesize                                     42
# file_metadata|md5                                         -43
# file_metadata|name                                         43
# file_metadata|previous_attempt_id                         -32
# file_metadata|request_id                                   43
# file_metadata|request_type                                 43
# file_metadata|scope                                        43
# file_metadata|src_rse                                      43
# file_metadata|src_rse_id                                   43
# file_metadata|src_type                                     43
# is_recoverable                                             38
# job_m_replica                                              21
# job_metadata                                               -2
# job_metadata|issuer                                         4
# job_metadata|multi_sources                                 38
# job_state                                                 -13
# nstreams                                                   39
# retry                                                      -1
# retry_max                                                  15
# src_hostname                                                8
# src_site_name                                               0
# src_srm_v                                                  -5
# src_url                                                     0
# srm_space_token_dst                                        48
# srm_space_token_src                                        12
# t_channel                                                  -1
# t_error_code                                              -12
# t_timeout                                                  35
# tcp_buf_size                                                7
# time_srm_fin_st                                            50
# time_srm_prep_st                                            6
# timestamp_checksum_dest_st                                100
# timestamp_chk_src_st                                       49
# user_dn                                                    -6
# vo                                                          9
# timestamp_tr_st                                            44
#
#                                    timestamp_chk_src_st  user_dn   vo  \
# block_size                                            0        0    0
# buf_size                                             14        1    6
# channel_type                                          0        0    0
# chk_timeout                                         -36        4  -18
# dest_srm_v                                          -16        0   -7
# dst_hostname                                        -37       11  -38
# dst_site_name                                         0        0    0
# dst_url                                               0        1    0
# endpnt                                              -24        4   27
# f_size                                                4        7    0
# file_metadata                                        93      -11   48
# file_metadata|activity                               95      -12   50
# file_metadata|adler32                                 0        0    0
# file_metadata|dest_rse_id                            95      -12   50
# file_metadata|dst_rse                                95      -12   50
# file_metadata|dst_type                               95      -12   50
# file_metadata|filesize                               28       -3   15
# file_metadata|md5                                   -95       12  -50
# file_metadata|name                                   95      -12   50
# file_metadata|previous_attempt_id                    47       -6   25
# file_metadata|request_id                             95      -12   50
# file_metadata|request_type                           95      -12   50
# file_metadata|scope                                  95      -12   50
# file_metadata|src_rse                                95      -12   50
# file_metadata|src_rse_id                             95      -12   50
# file_metadata|src_type                               95      -12   50
# is_recoverable                                       26      -20   37
# job_m_replica                                        46       -5   24
# job_metadata                                         16       -1   54
# job_metadata|issuer                                  23       -3   41
# job_metadata|multi_sources                           84      -10   44
# job_state                                           -37        4  -19
# nstreams                                             16        0    6
# retry                                                -2       -1  -13
# retry_max                                             7       -5  -62
# src_hostname                                         12        2    3
# src_site_name                                         0        0    0
# src_srm_v                                             6       -8   -1
# src_url                                               0        0    2
# srm_space_token_dst                                  98      -12   36
# srm_space_token_src                                   5       -4  -50
# t_channel                                             7       -1    1
# t_error_code                                         10        0    5
# t_timeout                                            12        2    6
# tcp_buf_size                                         14        1    6
# time_srm_fin_st                                     -36       11  -19
# time_srm_prep_st                                     14        1    5
# timestamp_checksum_dest_st                           49       -6    9
# timestamp_chk_src_st                                100      -12   36
# user_dn                                             -12      100  -10
# vo                                                   36      -10  100
# timestamp_tr_st                                     -35       13  -19
#
#                                    timestamp_tr_st
# block_size                                       0
# buf_size                                        16
# channel_type                                     0
# chk_timeout                                     23
# dest_srm_v                                     -15
# dst_hostname                                    40
# dst_site_name                                    0
# dst_url                                          2
# endpnt                                           5
# f_size                                          21
# file_metadata                                  -39
# file_metadata|activity                         -39
# file_metadata|adler32                            0
# file_metadata|dest_rse_id                      -38
# file_metadata|dst_rse                          -39
# file_metadata|dst_type                         -39
# file_metadata|filesize                          17
# file_metadata|md5                               39
# file_metadata|name                             -39
# file_metadata|previous_attempt_id              -68
# file_metadata|request_id                       -39
# file_metadata|request_type                     -39
# file_metadata|scope                            -39
# file_metadata|src_rse                          -39
# file_metadata|src_rse_id                       -39
# file_metadata|src_type                         -39
# is_recoverable                                  12
# job_m_replica                                  -17
# job_metadata                                    -9
# job_metadata|issuer                             -9
# job_metadata|multi_sources                     -33
# job_state                                       16
# nstreams                                        28
# retry                                           -2
# retry_max                                        6
# src_hostname                                    -6
# src_site_name                                    0
# src_srm_v                                      -22
# src_url                                          0
# srm_space_token_dst                            -37
# srm_space_token_src                              5
# t_channel                                       -8
# t_error_code                                    13
# t_timeout                                       27
# tcp_buf_size                                    16
# time_srm_fin_st                                 89
# time_srm_prep_st                                15
# timestamp_checksum_dest_st                      44
# timestamp_chk_src_st                           -35
# user_dn                                         13
# vo                                             -19
# timestamp_tr_st                                100
#
# [52 rows x 52 columns]

# %% [markdown]
# Removing colums no variance
# ----

# %%
# from sklearn.feature_selection import VarianceThreshold
# sel = VarianceThreshold()
# sel.fit_transform(dataframe)

# TODO: No  idea which columns it removes, need more reading

# %% [markdown]
# Trying scaling on data
# ------

# %%
matrix_to_scale = dataframe.as_matrix()
matrix_to_scale
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   8.83010025e+01, ...,
#           8.79453964e+01,   8.77032394e+01,  -2.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   8.83010025e+01, ...,
#           8.79453964e+01,   8.77032394e+01,   1.46715102e+12],
#        [  0.00000000e+00,   0.00000000e+00,   8.83010025e+01, ...,
#           8.79453964e+01,   8.77032394e+01,  -2.00000000e+00],
#        ...,
#        [  0.00000000e+00,   0.00000000e+00,   8.83010025e+01, ...,
#           8.84060211e+01,   8.76441803e+01,   1.46715129e+12],
#        [  0.00000000e+00,   0.00000000e+00,   8.83010025e+01, ...,
#           8.79453964e+01,   8.77032394e+01,   1.46714329e+12],
#        [  0.00000000e+00,   0.00000000e+00,   8.83010025e+01, ...,
#           8.79453964e+01,   8.77032394e+01,   1.46715129e+12]], dtype=float32)

# %%
scale_X = preprocessing.scale(matrix_to_scale)
# type(matrix_to_scale)


min_max_scaler = preprocessing.MinMaxScaler()
X_train_minmax = min_max_scaler.fit_transform(matrix_to_scale)
X_train_minmax
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-fdca192af9a4> in <module>()
# ----> 1 scale_X = preprocessing.scale(matrix_to_scale)
#       2 # type(matrix_to_scale)
#       3
#       4
#       5 min_max_scaler = preprocessing.MinMaxScaler()
#
# /home/zygis/anaconda3/lib/python3.5/site-packages/sklearn/preprocessing/data.py in scale(X, axis, with_mean, with_std, copy)
#     127     X = check_array(X, accept_sparse='csr', copy=copy, ensure_2d=False,
#     128                     warn_on_dtype=True, estimator='the scale function',
# --> 129                     dtype=FLOAT_DTYPES)
#     130     if sparse.issparse(X):
#     131         if with_mean:
#
# /home/zygis/anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     396                              % (array.ndim, estimator_name))
#     397         if force_all_finite:
# --> 398             _assert_all_finite(array)
#     399
#     400     shape_repr = _shape_repr(array.shape)
#
# /home/zygis/anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      52             and not np.isfinite(X).all()):
#      53         raise ValueError("Input contains NaN, infinity"
# ---> 54                          " or a value too large for %r." % X.dtype)
#      55
#      56
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %% [markdown]
# ML learning phase
# -----

# %% [markdown]
# Now we are preparing to matrixes to for analysis by transforming them to ndarray. One will be data, another one will be our target:

# %%
X = dataframe.as_matrix()
y = target.as_matrix()

# %% [markdown]
# Just to be sure, lets see how prepared data looks:

# %%
X

# %%
y

# %% [markdown]
# Now we will split data to train/test:

# %%
from sklearn.cross_validation import train_test_split 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=92)
len(X_train), len(X_test)

# %% [markdown]
# Now we are prepared. Lets check some models and see results.
#
# Algortihm benchmark
# --------
# I used the following chart to select different regression algorithms for checking.

# %%
from IPython.display import Image
Image("http://scikit-learn.org/dev/_static/ml_map.png")

# %% [markdown]
# RandomForestRegressor
# ----------------
# First lets see how well RandomForestRegressor performs.

# %%
# Fit a Random Forest 
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

output=[]
# comparing real values to predicted
for answ, pred in zip(y_test, y_pred): 
    output.append( (answ,pred) )
display(output[:100])

# %% [markdown]
# Error rates of this model:

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error 
print('MAE: {0}'.format(mean_absolute_error(y_test,y_pred)))
print ('RMSE: {0}'.format(mean_squared_error(y_test,y_pred)))

# %% [markdown]
# SGD Regressor
# -------------

# %%
from sklearn import linear_model
model = linear_model.SGDRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)


output=[]
# comparing real values to predicted
for answ, pred in zip(y_test, y_pred): 
    output.append( (answ,pred) )
display(output[:100])

# %%
print('MAE: {0}'.format(mean_absolute_error(y_test,y_pred)))
print ('RMSE: {0}'.format(mean_squared_error(y_test,y_pred)))

# %% [markdown]
# Cearly, not very good

# %% [markdown]
# ElasticNet
# -----------

# %%
from sklearn import linear_model
model = linear_model.Lasso(alpha=0.5)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

output=[]
# comparing real values to predicted
for answ, pred in zip(y_test, y_pred): 
    output.append( (answ,pred) )
display(output[:100])

# %%
print('MAE: {0}'.format(mean_absolute_error(y_test,y_pred)))
print ('RMSE: {0}'.format(mean_squared_error(y_test,y_pred)))

# %% [markdown]
# Ridge
# -----

# %%
from sklearn import linear_model
model = linear_model.Ridge(alpha=1.0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

output=[]
# comparing real values to predicted
for answ, pred in zip(y_test, y_pred): 
    output.append( (answ,pred) )
display(output[:100])

# %%
print('MAE: {0}'.format(mean_absolute_error(y_test,y_pred)))
print ('RMSE: {0}'.format(mean_squared_error(y_test,y_pred)))

# %% [markdown]
# Conclusion
# ------
# So random forest is the only ML algorithm that give predictions not so far away.

# %% [markdown]
# Resources
# -------
# - http://stackoverflow.com/questions/11023411/how-to-import-csv-data-file-into-scikit-learn
# - http://pandas.pydata.org/
# - http://scikit-learn.org/stable/modules/scaling_strategies.html
# - http://stackoverflow.com/questions/9590114/importance-of-pca-or-svd-in-machine-learning
# - http://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_error.html
# - http://scikit-learn.org/stable/modules/feature_selection.html#variance-threshold
