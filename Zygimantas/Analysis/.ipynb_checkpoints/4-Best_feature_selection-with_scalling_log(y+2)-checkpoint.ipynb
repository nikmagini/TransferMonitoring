# %% [markdown]
# # Analysis of most promenant algorithm
#
# In this notebook I will document the search for best algrothm to analyse TransferMonitoring data

# %% [markdown]
# ## Loading and initial setup

# %%
# %matplotlib inline
# Here i keep prepared csv file for ML
f = open('/home/zygis/_Projektai/CERN/TransferMonitoring/Zygimantas/data/output/out.csv')

import numpy as np
import pandas as pd
from pandas import read_csv
from IPython.display import display, HTML

# in order to display of dataframe
pd.set_option('display.max_columns', 60)
pd.set_option('display.max_rows', 30)

dataframe = read_csv(f).astype(np.float32)

# to see struckture of data, uncoment
# dataframe 

# save headers to seperate list
original_headers = list(dataframe.columns.values)

# to see list of headeers, uncoment
print(len(original_headers))
display(original_headers)
# Out:
# 53
# ['block_size',
#  'buf_size',
#  'channel_type',
#  'chk_timeout',
#  'dest_srm_v',
#  'dst_hostname',
#  'dst_site_name',
#  'dst_url',
#  'endpnt',
#  'f_size',
#  'file_metadata',
#  'file_metadata|activity',
#  'file_metadata|adler32',
#  'file_metadata|dest_rse_id',
#  'file_metadata|dst_rse',
#  'file_metadata|dst_type',
#  'file_metadata|filesize',
#  'file_metadata|md5',
#  'file_metadata|name',
#  'file_metadata|previous_attempt_id',
#  'file_metadata|request_id',
#  'file_metadata|scope',
#  'file_metadata|src_rse',
#  'file_metadata|src_type',
#  'job_m_replica',
#  'job_metadata',
#  'job_metadata|issuer',
#  'job_metadata|multi_sources',
#  'job_state',
#  'nstreams',
#  'retry',
#  'retry_max',
#  'src_hostname',
#  'src_site_name',
#  'src_srm_v',
#  'src_url',
#  'srm_space_token_dst',
#  'srm_space_token_src',
#  't_channel',
#  't_error_code',
#  't_timeout',
#  'tcp_buf_size',
#  'time_srm_fin_st',
#  'time_srm_prep_st',
#  'timestamp_checksum_dest_st',
#  'timestamp_chk_src_st',
#  'tr_timestamp_complete',
#  'tr_timestamp_start',
#  'user_dn',
#  'vo',
#  'tr_id',
#  'timestamp_tr_st',
#  'timestamp_tr_dlt']

# %% [markdown]
# # Preprocesing step
# ## Check if data is missing any value

# %%
dataframe.isnull().any()
# Out:
# block_size                    False
# buf_size                      False
# channel_type                  False
# chk_timeout                   False
# dest_srm_v                    False
# dst_hostname                  False
# dst_site_name                 False
# dst_url                       False
# endpnt                        False
# f_size                        False
# file_metadata                 False
# file_metadata|activity        False
# file_metadata|adler32         False
# file_metadata|dest_rse_id     False
# file_metadata|dst_rse         False
#                               ...
# t_channel                     False
# t_error_code                  False
# t_timeout                     False
# tcp_buf_size                  False
# time_srm_fin_st               False
# time_srm_prep_st              False
# timestamp_checksum_dest_st    False
# timestamp_chk_src_st          False
# tr_timestamp_complete         False
# tr_timestamp_start            False
# user_dn                       False
# vo                            False
# tr_id                         False
# timestamp_tr_st               False
# timestamp_tr_dlt              False
# dtype: bool

# %%
# -- uncoment to see data types
# types = dataframe.dtypes
# types

# %%
try: 
    # if true, dataframe contains infinite numbers(bad)     
    print(np.all(np.isfinite(dataframe)))
except:
    pass
# Out:
# True

# %%
try:    
    print(np.any(np.isnan(dataframe)))
except:
    pass
# Out:
# False

# %% [markdown]
# Selecting importat features
# ---------
#
# Since our datasets is quit big, we should reduce the values inorder to save resources and increase computational speed.

# %% [markdown]
# First we drop out unvanted columns that for sure will not tell anything important for us.

# %%
# fields that are output and can't be used as input
drop_list_output = ['tr_id','t_error_code','tr_timestamp_complete','timestamp_tr_st']
for el in drop_list_output:
    try:
        dataframe = dataframe.drop(el, axis=1)
    except:
        print('There was no such field:{}'.format(el))

# fields that are non vairiating and useless
drop_list_non_variate = ['block_size','buf_size','channel_type',
                            'dst_site_name','src_site_name','t_timeout','src_srm_v','tcp_buf_size']
for el in drop_list_non_variate:
    try:
        dataframe = dataframe.drop(el, axis=1)
    except:
        print('There was no such field:{}'.format(el))

# fields that correlating and useless        
drop_list_correlating =['file_metadata|name','file_metadata|dst_type',
                        'file_metadata|request_id','file_metadata|src_type',
                        'file_metadata|md5','file_metadata|src_rse',
                        'file_metadata|dst_rse','file_metadata|activity']
for el in drop_list_correlating:
    try:
        dataframe = dataframe.drop(el, axis=1)
    except:
        print('There was no such field:{}'.format(el))


# a=list(dataframe.columns.values)

# %% [markdown]
# dataframe itself

# %%
from sklearn import preprocessing
dataframe
# Out:
#         chk_timeout  dest_srm_v  dst_hostname    dst_url     endpnt  \
# 0               0.0   87.146263     85.467171  87.859352  88.701981
# 1               0.0   87.146263     88.026329  88.401627  88.701981
# 2               0.0   87.146263     88.678413  87.502213  88.701981
# 3            1800.0   87.146263     87.771095  87.942703  86.832253
# 4            1800.0   87.146263     87.771095  86.337303  86.832253
# 5            1800.0   87.146263     88.303612  83.947197  88.678986
# 6            1800.0   87.146263     88.485664  85.674934  88.678986
# 7            1800.0   87.146263     88.485664  88.357704  88.678986
# 8            1800.0   87.146263     88.303612  86.443489  88.678986
# 9            1800.0   87.146263     88.485664  88.654030  88.678986
# 10           1800.0   87.146263     87.771095  87.418221  86.832253
# 11           1800.0   87.146263     88.707619  86.270355  88.678986
# 12           1800.0   87.146263     87.993652  87.193047  88.443825
# 13           1800.0   87.146263     87.892143  87.950920  88.443825
# 14              0.0   87.146263     88.469917  86.567146  88.701981
# ...             ...         ...           ...        ...        ...
# 685499          0.0   87.146263     88.469917  87.463219  88.701981
# 685500          0.0   87.146263     87.857178  88.410271  88.701981
# 685501          0.0   87.146263     87.857178  85.752159  88.701981
# 685502       1800.0   87.146263     88.054146  88.530869  88.443825
# 685503          0.0   87.146263     87.939865  88.388977  88.701981
# 685504          0.0   87.146263     88.469917  88.646149  88.701981
# 685505          0.0   87.146263     88.469917  88.559219  88.701981
# 685506          0.0   87.146263     87.857178  88.413078  88.701981
# 685507          0.0   87.146263     88.469917  88.149635  88.701981
# 685508          0.0   87.146263     88.469917  87.199852  88.701981
# 685509          0.0   87.146263     87.760818  86.625206  88.701981
# 685510       1800.0    0.000000     87.453415  88.050301  88.678986
# 685511       1800.0    0.000000     87.453415  85.490059  88.678986
# 685512          0.0   87.146263     87.760818  88.192627  88.701981
# 685513          0.0   87.146263     87.243660  87.032593  88.701981
#
#               f_size  file_metadata  file_metadata|activity  \
# 0       2.127745e+09            0.0               -1.000000
# 1       1.527680e+07           -1.0               88.283684
# 2       2.666740e+09           -1.0               88.384468
# 3       2.685586e+09            0.0               -1.000000
# 4       2.999112e+09            0.0               -1.000000
# 5       4.900000e+02           -1.0               87.834015
# 6       4.107188e+09           -1.0               88.384468
# 7       3.976307e+09           -1.0               88.384468
# 8       4.900000e+02           -1.0               87.834015
# 9       3.949724e+09           -1.0               88.384468
# 10      2.688047e+09            0.0               -1.000000
# 11      2.684355e+09            0.0               -1.000000
# 12      1.048576e+06           -1.0               87.629364
# 13      1.048576e+06           -1.0               87.629364
# 14      7.713745e+06           -1.0               87.195358
# ...              ...            ...                     ...
# 685499  9.907060e+05           -1.0               88.283684
# 685500  7.926800e+06           -1.0               87.195358
# 685501  4.967448e+07           -1.0               88.283684
# 685502  1.048576e+06           -1.0               87.629364
# 685503  1.166998e+09            0.0               -1.000000
# 685504  9.886290e+05           -1.0               88.283684
# 685505  8.132530e+05           -1.0               88.283684
# 685506  2.461311e+07           -1.0               88.283684
# 685507  1.569552e+09           -1.0               87.935211
# 685508  9.911810e+05           -1.0               88.283684
# 685509  2.591725e+07            0.0               -1.000000
# 685510  2.673041e+07           -1.0               88.283684
# 685511  2.254475e+07           -1.0               88.283684
# 685512  2.395177e+07            0.0               -1.000000
# 685513  2.811935e+06            0.0               -1.000000
#
#         file_metadata|adler32  file_metadata|dest_rse_id  \
# 0                   -1.000000                  -1.000000
# 1                   87.456703                  86.558624
# 2                   88.599884                  86.596008
# 3                   -1.000000                  -1.000000
# 4                   -1.000000                  -1.000000
# 5                   88.597610                  88.207535
# 6                   86.513412                  86.722740
# 7                   85.491241                  86.722740
# 8                   88.087425                  88.207535
# 9                   88.202805                  86.722740
# 10                  -1.000000                  -1.000000
# 11                  -1.000000                  -1.000000
# 12                  87.967369                  87.439453
# 13                  88.621300                  87.508194
# 14                  87.553017                  87.427193
# ...                       ...                        ...
# 685499              86.121292                  87.427193
# 685500              88.226746                  87.904297
# 685501              85.055420                  87.904297
# 685502              87.840706                  88.374283
# 685503              -1.000000                  -1.000000
# 685504              87.624153                  87.427193
# 685505              86.920273                  87.427193
# 685506              88.519119                  87.904297
# 685507              87.332054                  87.427193
# 685508              87.748245                  87.427193
# 685509              -1.000000                  -1.000000
# 685510              88.289627                  87.533508
# 685511              87.668533                  87.533508
# 685512              -1.000000                  -1.000000
# 685513              -1.000000                  -1.000000
#
#         file_metadata|dst_rse  file_metadata|dst_type  file_metadata|filesize  \
# 0                   -1.000000               -1.000000           -1.000000e+00
# 1                   87.638855               86.892502            1.527680e+07
# 2                   87.110565               86.892502            2.666740e+09
# 3                   -1.000000               -1.000000           -1.000000e+00
# 4                   -1.000000               -1.000000           -1.000000e+00
# 5                   86.590256               86.892502            4.900000e+02
# 6                   86.687187               86.892502            4.107188e+09
# 7                   86.687187               86.892502            3.976307e+09
# 685507                1.441318e+12          1.441317e+12        1.441317e+12
# 685508                1.441318e+12          1.441318e+12        1.441318e+12
# 685509                0.000000e+00          0.000000e+00        1.441318e+12
# 685510                1.441318e+12          1.441318e+12        1.441318e+12
# 685511                1.441318e+12          1.441318e+12        1.441318e+12
# 685512                0.000000e+00          0.000000e+00        1.441318e+12
# 685513                0.000000e+00          0.000000e+00        1.441317e+12
#
#           user_dn         vo  timestamp_tr_dlt
# 0       88.116028  87.644180          212183.0
# 1       87.945396  87.703239            4990.0
# 2       87.945396  87.703239           49873.0
# 3       87.995178  87.644180           18264.0
# 4       87.995178  87.644180           67894.0
# 5       87.945396  87.703239            7397.0
# 6       87.945396  87.703239          148101.0
# 7       87.945396  87.703239          247014.0
# 8       87.945396  87.703239            6980.0
# 9       87.945396  87.703239          241822.0
# 10      87.995178  87.644180           18324.0
# 11      88.425674  87.644180           67385.0
# 12      87.945396  87.703239            7545.0
# 13      87.945396  87.703239            4685.0
# 14      87.945396  87.703239           11182.0
# ...           ...        ...               ...
# 685499  87.945396  87.703239            2017.0
# 685500  87.945396  87.703239            2353.0
# 685501  87.945396  87.703239             979.0
# 685502  87.945396  87.703239            3387.0
# 685503  87.691620  87.644180              -1.0
# 685504  87.945396  87.703239            2461.0
# 685505  87.945396  87.703239            6530.0
# 685506  87.945396  87.703239            1908.0
# 685507  87.945396  87.703239          332416.0
# 685508  87.945396  87.703239            2054.0
# 685509  88.229492  87.644180            3675.0
# 685510  87.945396  87.703239            4975.0
# 685511  87.945396  87.703239            8248.0
# 685512  87.814262  87.644180              -1.0
# 685513  88.433640  87.644180           52993.0
#
# [685514 rows x 41 columns]

# %% [markdown]
# Now we pop out our target column, we will use it for later.

# %%
# from dataframe pop target column and transform to ndarray
target=dataframe.pop('timestamp_tr_dlt')

# %% [markdown]
# As an end result we will process this kind of matrix.

# %%
prepared_headers = list(dataframe.columns.values)
# prepared_headers

# %% [markdown]
# More checking on dataframe:

# %%
# corr = dataframe.corr().fillna(0).mul(100).astype(int)
corr = dataframe.corr().fillna(0).mul(100).astype(int)
corr
# Out:
#                             chk_timeout  dest_srm_v  dst_hostname  dst_url  \
# chk_timeout                         100         -20            23        0
# dest_srm_v                          -20         100             4        0
# dst_hostname                         23           4           100        0
# dst_url                               0           0             0      100
# endpnt                              -36          -9             0        0
# f_size                               17          -4             0        0
# file_metadata                       -22           3           -42        0
# file_metadata|activity               22          -3            42        0
# file_metadata|adler32                 1           0             2        0
# file_metadata|dest_rse_id            22          -2            42        0
# file_metadata|dst_rse                22          -3            42        0
# file_metadata|dst_type               22          -3            42        0
# file_metadata|filesize               12          -1             8        0
# file_metadata|md5                    22          -3            42        0
# file_metadata|name                   22          -3            42        0
# ...                                 ...         ...           ...      ...
# nstreams                             39         -19            -3        0
# retry                                 0           0             0        0
# retry_max                             0           0             0        0
# src_hostname                          6          -5             3        0
# src_url                               0           0             0        0
# srm_space_token_dst                  24          -1            43        0
# srm_space_token_src                   8           2             1        0
# t_channel                            -2           2           -11        0
# time_srm_fin_st                      31          -8            -7        0
# time_srm_prep_st                      0          -1            -4        0
# timestamp_checksum_dest_st           44         -17            37        0
# timestamp_chk_src_st                 29         -13            48        0
# tr_timestamp_start                  -17          -5            -1        0
# user_dn                             -18          19           -16        0
# vo                                  -26           3           -58        0
#
#                             endpnt  f_size  file_metadata  \
# chk_timeout                    -36      17            -22
# dest_srm_v                      -9      -4              3
# dst_hostname                     0       0            -42
# dst_url                          0       0              0
# endpnt                         100     -20            -35
# f_size                         -20     100             21
# file_metadata                  -35      21            100
# file_metadata|activity          35     -21            -99
# file_metadata|adler32            2      -1             -7
# file_metadata|dest_rse_id       35     -22            -99
# file_metadata|dst_rse           35     -21            -99
# file_metadata|dst_type          35     -21            -99
# file_metadata|filesize           4      71            -21
# file_metadata|md5               35     -21           -100
# file_metadata|name              35     -21            -99
# ...                            ...     ...            ...
# nstreams                       -36      58             27
# retry                            0       0              0
# retry_max                        0       3              1
# src_hostname                     0     -11            -18
# src_url                          0       0              0
# srm_space_token_dst             25     -22            -96
# srm_space_token_src            -46      -4             16
# t_channel                        4      -8              1
# time_srm_fin_st                -11       9              3
# time_srm_prep_st                -2      -1            -14
# timestamp_checksum_dest_st       8      -7            -66
# timestamp_chk_src_st            16     -18            -89
# tr_timestamp_start              12      -5              2
# user_dn                         29     -18            -17
# vo                              44     -14              0
#
#                             file_metadata|activity  file_metadata|adler32  \
# chk_timeout                                     22                      1
# dest_srm_v                                      -3                      0
# dst_hostname                                    42                      2
# dst_url                                          0                      0
# endpnt                                          35                      2
# f_size                                         -21                     -1
# file_metadata                                  -99                     -7
# file_metadata|activity                         100                      7
# file_metadata|adler32                            7                    100
# file_metadata|dest_rse_id                       99                      7
# file_metadata|dst_rse                           99                      7
# file_metadata|dst_type                          99                      7
# file_metadata|filesize                          21                      1
# file_metadata|md5                               99                      7
# file_metadata|name                              99                      7
# ...                                            ...                    ...
# nstreams                                       -27                     -2
# retry                                            0                      0
# retry_max                                       -1                      0
# src_hostname                                    18                      1
# src_url                                          0                      0
# srm_space_token_dst                             96                      6
# srm_space_token_src                            -16                     -1
# t_channel                                       -1                      0
# time_srm_fin_st                                 -3                      0
# time_srm_prep_st                                14                      1
# timestamp_checksum_dest_st                      66                      4
# timestamp_chk_src_st                            89                      6
# tr_timestamp_start                              -2                      0
# user_dn                                         17                      1
# vo                                               0                      0
#
#                             file_metadata|dest_rse_id  file_metadata|dst_rse  \
# chk_timeout                                        22                     22
# dest_srm_v                                         -2                     -3
# dst_hostname                                       42                     42
# dst_url                                             0                      0
# endpnt                                             35                     35
# f_size                                            -22                    -21
# file_metadata                                     -99                    -99
# file_metadata|activity                             99                     99
# file_metadata|adler32                               7                      7
# file_metadata|dest_rse_id                         100                     99
# file_metadata|dst_rse                              99                    100
# file_metadata|dst_type                             99                     99
# file_metadata|filesize                             21                     21
# file_metadata|md5                                  99                     99
# file_metadata|name                                 99                     99
# ...                                               ...                    ...
# nstreams                                          -28                    -27
# retry                                               0                      0
# retry_max                                          -1                     -1
# src_hostname                                       18                     18
# src_url                                             0                      0
# srm_space_token_dst                                96                     96
# srm_space_token_src                               -16                    -16
# t_channel                                          -1                     -1
# time_srm_fin_st                                    -3                     -3
# time_srm_prep_st                                   14                     14
# timestamp_checksum_dest_st                         66                     66
# timestamp_chk_src_st                               89                     89
# tr_timestamp_start                                 -2                     -2
# user_dn                                            17                     17
# vo                                                  0                      0
#
#                             file_metadata|dst_type  file_metadata|filesize  \
# chk_timeout                                     22                      12
# dest_srm_v                                      -3                      -1
# dst_hostname                                    42                       8
# dst_url                                          0                       0
# endpnt                                          35                       4
# f_size                                         -21                      71
# file_metadata                                  -99                     -21
# file_metadata|activity                          99                      21
# file_metadata|adler32                            7                       1
# file_metadata|dest_rse_id                       99                      21
# file_metadata|dst_rse                           99                      21
# file_metadata|dst_type                         100                      21
# file_metadata|filesize                          21                     100
# file_metadata|md5                               99                      21
# file_metadata|name                              99                      21
# ...                                            ...                     ...
# nstreams                                       -27                      19
# retry                                            0                       0
# retry_max                                       -1                       0
# src_hostname                                    18                       1
# src_url                                          0                       0
# srm_space_token_dst                             96                      20
# srm_space_token_src                            -16                      -3
# t_channel                                       -1                      -4
# time_srm_fin_st                                 -3                       9
# time_srm_prep_st                                14                       2
# timestamp_checksum_dest_st                      66                      21
# timestamp_chk_src_st                            89                      19
# tr_timestamp_start                              -2                      -1
# user_dn                                         17                       3
# vo                                               0                       0
#
#                             file_metadata|md5  file_metadata|name  \
# chk_timeout                                22                  22
# dest_srm_v                                 -3                  -3
# dst_hostname                               42                  42
# dst_url                                     0                   0
# endpnt                                     35                  35
# f_size                                    -21                 -21
# file_metadata                            -100                 -99
# file_metadata|activity                     99                  99
# file_metadata|adler32                       7                   7
# file_metadata|dest_rse_id                  99                  99
# file_metadata|dst_rse                      99                  99
# file_metadata|dst_type                     99                  99
# file_metadata|filesize                     21                  21
# file_metadata|md5                         100                  99
# file_metadata|name                         99                 100
# ...                                       ...                 ...
# nstreams                                  -27                 -27
# retry                                       0                   0
# retry_max                                  -1                  -1
# src_hostname                               18                  18
# src_url                                     0                   0
# srm_space_token_dst                        96                  96
# srm_space_token_src                       -16                 -16
# t_channel                                  -1                  -1
# time_srm_fin_st                            -3                  -3
# time_srm_prep_st                           14                  14
# timestamp_checksum_dest_st                 66                  66
# timestamp_chk_src_st                       89                  89
# tr_timestamp_start                         -2                  -2
# user_dn                                    17                  17
# vo                                          0                   0
#
#                             file_metadata|previous_attempt_id  \
# chk_timeout                                               -27
# dest_srm_v                                                  8
# dst_hostname                                                9
# dst_url                                                     0
# endpnt                                                     11
# f_size                                                    -13
# file_metadata                                             -20
# file_metadata|activity                                     19
# file_metadata|adler32                                       1
# file_metadata|dest_rse_id                                  20
# file_metadata|dst_rse                                      19
# file_metadata|dst_type                                     20
# file_metadata|filesize                                     -6
# file_metadata|md5                                          20
# file_metadata|name                                         20
# ...                                                       ...
# nstreams                                                  -14
# retry                                                       0
# retry_max                                                   0
# src_hostname                                                8
# src_url                                                     0
# srm_space_token_dst                                        19
# srm_space_token_src                                        -3
# t_channel                                                   3
# time_srm_fin_st                                           -69
# time_srm_prep_st                                            0
# timestamp_checksum_dest_st                                -37
# timestamp_chk_src_st                                       17
# tr_timestamp_start                                          9
# user_dn                                                     3
# vo                                                          0
#
#                             file_metadata|request_id  file_metadata|scope  \
# chk_timeout                                       22                   22
# dest_srm_v                                        -3                   -3
# dst_hostname                                      42                   42
# dst_url                                            0                    0
# endpnt                                            35                   35
# f_size                                           -21                  -22
# file_metadata                                    -99                  -99
# file_metadata|activity                            99                   99
# file_metadata|adler32                              7                    7
# file_metadata|dest_rse_id                         99                   99
# file_metadata|dst_rse                             99                   99
# file_metadata|dst_type                            99                   99
# file_metadata|filesize                            21                   21
# file_metadata|md5                                 99                   99
# file_metadata|name                                99                   99
# ...                                              ...                  ...
# nstreams                                         -27                  -27
# retry                                              0                    0
# retry_max                                         -1                   -1
# src_hostname                                      18                   18
# src_url                                            0                    0
# srm_space_token_dst                               96                   96
# srm_space_token_src                              -16                  -16
# t_channel                                         -1                   -1
# time_srm_fin_st                                   -3                   -3
# time_srm_prep_st                                  14                   14
# timestamp_checksum_dest_st                        66                   66
# timestamp_chk_src_st                              89                   89
# tr_timestamp_start                                -2                   -2
# user_dn                                           17                   17
# vo                                                 0                    0
#
#                             file_metadata|src_rse  file_metadata|src_type  \
# chk_timeout                                    22                      22
# dest_srm_v                                     -2                      -3
# dst_hostname                                   42                      42
# dst_url                                         0                       0
# endpnt                                         35                      35
# f_size                                        -21                     -21
# file_metadata                                 -99                     -99
# file_metadata|activity                         99                      99
# file_metadata|adler32                           7                       7
# file_metadata|dest_rse_id                      99                      99
# file_metadata|dst_rse                          99                      99
# file_metadata|dst_type                         99                      99
# file_metadata|filesize                         21                      21
# file_metadata|md5                              99                      99
# file_metadata|name                             99                      99
# ...                                           ...                     ...
# nstreams                                      -27                     -27
# retry                                           0                       0
# retry_max                                      -1                      -1
# src_hostname                                   18                      18
# src_url                                         0                       0
# srm_space_token_dst                            96                      96
# srm_space_token_src                           -16                     -16
# t_channel                                      -1                      -1
# time_srm_fin_st                                -3                      -3
# time_srm_prep_st                               14                      14
# timestamp_checksum_dest_st                     66                      66
# timestamp_chk_src_st                           89                      89
# tr_timestamp_start                             -2                      -2
# user_dn                                        17                      17
# vo                                              0                       0
#
#                             job_m_replica  job_metadata  job_metadata|issuer  \
# chk_timeout                            -8             0                    0
# dest_srm_v                              0            -1                    1
# dst_hostname                           10           -49                   49
# dst_url                                 0             0                    0
# endpnt                                 16           -49                   49
# f_size                                 11            32                  -32
# file_metadata                         -37            79                  -79
# file_metadata|activity                 37           -79                   79
# file_metadata|adler32                   2            -5                    5
# file_metadata|dest_rse_id              37           -79                   79
# file_metadata|dst_rse                  37           -79                   79
# file_metadata|dst_type                 37           -79                   79
# file_metadata|filesize                 33           -17                   17
# file_metadata|md5                      37           -79                   79
# file_metadata|name                     37           -79                   79
# ...                                   ...           ...                  ...
# nstreams                               -6            42                  -41
# retry                                   0             0                    0
# retry_max                               0             1                   -1
# src_hostname                            5           -13                   13
# src_url                                 0             0                    0
# srm_space_token_dst                    36           -73                   74
# srm_space_token_src                    -6            20                  -20
# t_channel                              -3             1                   -1
# time_srm_fin_st                       -37             9                   -9
# time_srm_prep_st                        6           -12                   12
# timestamp_checksum_dest_st             -1           -46                   46
# timestamp_chk_src_st                   34           -63                   63
# tr_timestamp_start                      0            -5                    5
# user_dn                                 6           -22                   22
# vo                                      0            12                  -12
#
#                             job_metadata|multi_sources  job_state  nstreams  \
# chk_timeout                                          8          4        39
# dest_srm_v                                          -1          0       -19
# dst_hostname                                        31         -7        -3
# dst_url                                              0          0         0
# endpnt                                              31        -12       -36
# f_size                                              -6        -10        58
# file_metadata                                      -83         29        27
# file_metadata|activity                              83        -29       -27
# file_metadata|adler32                                5         -2        -2
# file_metadata|dest_rse_id                           83        -29       -28
# file_metadata|dst_rse                               83        -29       -27
# file_metadata|dst_type                              83        -29       -27
# file_metadata|filesize                              33        -28        19
# file_metadata|md5                                   83        -29       -27
# file_metadata|name                                  83        -29       -27
# ...                                                ...        ...       ...
# nstreams                                           -20          4       100
# retry                                                0          0         0
# retry_max                                           -1          0         3
# src_hostname                                        14         -3        -9
# src_url                                              0          0         0
# srm_space_token_dst                                 80        -28       -27
# srm_space_token_src                                -13          4         2
# t_channel                                           -2          6        -9
# time_srm_fin_st                                    -24         26        16
# time_srm_prep_st                                    12         -5         9
# timestamp_checksum_dest_st                          39          0        -9
# timestamp_chk_src_st                                74        -26       -20
# tr_timestamp_start                                   0          0        -7
# user_dn                                             14         -5       -34
# vo                                                   0          0       -18
#
#                             retry  retry_max  src_hostname  src_url  \
# chk_timeout                     0          0             6        0
# dest_srm_v                      0          0            -5        0
# dst_hostname                    0          0             3        0
# dst_url                         0          0             0        0
# endpnt                          0          0             0        0
# f_size                          0          3           -11        0
# file_metadata                   0          1           -18        0
# file_metadata|activity          0         -1            18        0
# file_metadata|adler32           0          0             1        0
# file_metadata|dest_rse_id       0         -1            18        0
# file_metadata|dst_rse           0         -1            18        0
# file_metadata|dst_type          0         -1            18        0
# file_metadata|filesize          0          0             1        0
# file_metadata|md5               0         -1            18        0
# file_metadata|name              0         -1            18        0
# ...                           ...        ...           ...      ...
# nstreams                        0          3            -9        0
# retry                         100         17             0        0
# retry_max                      17        100             0        0
# src_hostname                    0          0           100        0
# src_url                         0          0             0      100
# srm_space_token_dst             0          0            19        0
# srm_space_token_src             1          9             2        0
# t_channel                       0          0             1        0
# time_srm_fin_st                 0          0            -6        0
# time_srm_prep_st                0          0             0        0
# timestamp_checksum_dest_st      0          0            11        0
# timestamp_chk_src_st            0          0            17        0
# tr_timestamp_start              0          0            -4        0
# user_dn                         0          1             2        0
# vo                              0          0             0        0
#
#                             srm_space_token_dst  srm_space_token_src  \
# chk_timeout                                  24                    8
# dest_srm_v                                   -1                    2
# dst_hostname                                 43                    1
# dst_url                                       0                    0
# endpnt                                       25                  -46
# f_size                                      -22                   -4
# file_metadata                               -96                   16
# file_metadata|activity                       96                  -16
# file_metadata|adler32                         6                   -1
# file_metadata|dest_rse_id                    96                  -16
# file_metadata|dst_rse                        96                  -16
# file_metadata|dst_type                       96                  -16
# file_metadata|filesize                       20                   -3
# file_metadata|md5                            96                  -16
# file_metadata|name                           96                  -16
# ...                                         ...                  ...
# nstreams                                    -27                    2
# retry                                         0                    1
# retry_max                                     0                    9
# src_hostname                                 19                    2
# src_url                                       0                    0
# srm_space_token_dst                         100                   -6
# srm_space_token_src                          -6                  100
# t_channel                                    -2                   -1
# time_srm_fin_st                              -2                    1
# time_srm_prep_st                             14                    1
# timestamp_checksum_dest_st                   68                    5
# timestamp_chk_src_st                         90                    5
# tr_timestamp_start                           -2                    1
# user_dn                                      15                   -4
# vo                                          -11                  -34
#
#                             t_channel  time_srm_fin_st  time_srm_prep_st  \
# chk_timeout                        -2               31                 0
# dest_srm_v                          2               -8                -1
# dst_hostname                      -11               -7                -4
# dst_url                             0                0                 0
# endpnt                              4              -11                -2
# f_size                             -8                9                -1
# file_metadata                       1                3               -14
# file_metadata|activity             -1               -3                14
# file_metadata|adler32               0                0                 1
# file_metadata|dest_rse_id          -1               -3                14
# file_metadata|dst_rse              -1               -3                14
# file_metadata|dst_type             -1               -3                14
# file_metadata|filesize             -4                9                 2
# file_metadata|md5                  -1               -3                14
# file_metadata|name                 -1               -3                14
# ...                               ...              ...               ...
# nstreams                           -9               16                 9
# retry                               0                0                 0
# retry_max                           0                0                 0
# src_hostname                        1               -6                 0
# src_url                             0                0                 0
# srm_space_token_dst                -2               -2                14
# srm_space_token_src                -1                1                 1
# t_channel                         100               -4                 0
# time_srm_fin_st                    -4              100                30
# time_srm_prep_st                    0               30               100
# timestamp_checksum_dest_st         -4               55                16
# timestamp_chk_src_st               -1                1                21
# tr_timestamp_start                  2              -10                -3
# user_dn                             3               -3               -11
# vo                                 16                4                 5
#
#                             timestamp_checksum_dest_st  timestamp_chk_src_st  \
# chk_timeout                                         44                    29
# dest_srm_v                                         -17                   -13
# dst_hostname                                        37                    48
# dst_url                                              0                     0
# endpnt                                               8                    16
# f_size                                              -7                   -18
# file_metadata                                      -66                   -89
# file_metadata|activity                              66                    89
# file_metadata|adler32                                4                     6
# file_metadata|dest_rse_id                           66                    89
# file_metadata|dst_rse                               66                    89
# file_metadata|dst_type                              66                    89
# file_metadata|filesize                              21                    19
# file_metadata|md5                                   66                    89
# file_metadata|name                                  66                    89
# ...                                                ...                   ...
# nstreams                                            -9                   -20
# retry                                                0                     0
# retry_max                                            0                     0
# src_hostname                                        11                    17
# src_url                                              0                     0
# srm_space_token_dst                                 68                    90
# srm_space_token_src                                  5                     5
# t_channel                                           -4                    -1
# time_srm_fin_st                                     55                     1
# time_srm_prep_st                                    16                    21
# timestamp_checksum_dest_st                         100                    76
# timestamp_chk_src_st                                76                   100
# tr_timestamp_start                                  -6                    -1
# user_dn                                              0                     2
# vo                                                 -14                   -17
#
#                             tr_timestamp_start  user_dn   vo
# chk_timeout                                -17      -18  -26
# dest_srm_v                                  -5       19    3
# dst_hostname                                -1      -16  -58
# dst_url                                      0        0    0
# endpnt                                      12       29   44
# f_size                                      -5      -18  -14
# file_metadata                                2      -17    0
# file_metadata|activity                      -2       17    0
# file_metadata|adler32                        0        1    0
# file_metadata|dest_rse_id                   -2       17    0
# file_metadata|dst_rse                       -2       17    0
# file_metadata|dst_type                      -2       17    0
# file_metadata|filesize                      -1        3    0
# file_metadata|md5                           -2       17    0
# file_metadata|name                          -2       17    0
# ...                                        ...      ...  ...
# nstreams                                    -7      -34  -18
# retry                                        0        0    0
# retry_max                                    0        1    0
# src_hostname                                -4        2    0
# src_url                                      0        0    0
# srm_space_token_dst                         -2       15  -11
# srm_space_token_src                          1       -4  -34
# t_channel                                    2        3   16
# time_srm_fin_st                            -10       -3    4
# time_srm_prep_st                            -3      -11    5
# timestamp_checksum_dest_st                  -6        0  -14
# timestamp_chk_src_st                        -1        2  -17
# tr_timestamp_start                         100        2    2
# user_dn                                      2      100   24
# vo                                           2       24  100
#
# [40 rows x 40 columns]

# %% [markdown]
# Lets see corelation matrix, ploted
# ------

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# corr = pd.DataFrame(X_noVariance).corr().fillna(0).mul(100).astype(int)


cg = sns.clustermap(figsize=(25,25),data=corr, annot=True, fmt='d', cmap='Reds', linewidths=.5)
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
plt
sns.plt.show()

# %% [markdown]
# Checking for colums with no variance
# ----

# %%
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold()
# X_noVariance = sel.fit_transform(dataframe) # get new array
X_noVariance = sel.fit(dataframe) # get treshold with support


support_list = sel.get_support()
a= [i for i,x in enumerate(support_list) if x == 0]
# atributes with 0 change
for i in a:
    print(i,original_headers[i])

# %% [markdown]
# ## Removing non variating values and correlation

# %% [markdown]
# Trying scaling on data
# ------

# %%
matrix_to_scale = dataframe.as_matrix()
# matrix_to_scale

# %%
# scale_X = preprocessing.scale(matrix_to_scale)
# # type(matrix_to_scale)
# scale_X

#  scale between [0;1]
min_max_scaler = preprocessing.MinMaxScaler()
X_scalled = min_max_scaler.fit_transform(matrix_to_scale)
X_scalled
# Out:
# array([[ 0.        ,  1.        ,  0.31715965, ...,  0.3671875 ,
#          0.93359184,  0.56125641],
#        [ 0.        ,  1.        ,  0.85492325, ...,  0.375     ,
#          0.91484737,  0.61546326],
#        [ 0.        ,  1.        ,  0.99194717, ...,  0.37109375,
#          0.91484737,  0.61546326],
#        ...,
#        [ 1.        ,  0.        ,  0.73453522, ...,  1.        ,
#          0.91484737,  0.61546326],
#        [ 0.        ,  1.        ,  0.79913139, ...,  0.99609375,
#          0.90044212,  0.56125641],
#        [ 0.        ,  1.        ,  0.6904583 , ...,  0.98828125,
#          0.96848297,  0.56125641]], dtype=float32)

# %% [markdown]
# ML learning phase
# -----

# %% [markdown]
# Now we are preparing to matrixes to for analysis by transforming them to ndarray. One will be data, another one will be our target:

# %%
X = X_scalled
y = target.as_matrix()

# %% [markdown]
# Just to be sure, lets see how prepared data looks:

# %%
X
# Out:
# array([[ 0.        ,  1.        ,  0.31715965, ...,  0.3671875 ,
#          0.93359184,  0.56125641],
#        [ 0.        ,  1.        ,  0.85492325, ...,  0.375     ,
#          0.91484737,  0.61546326],
#        [ 0.        ,  1.        ,  0.99194717, ...,  0.37109375,
#          0.91484737,  0.61546326],
#        ...,
#        [ 1.        ,  0.        ,  0.73453522, ...,  1.        ,
#          0.91484737,  0.61546326],
#        [ 0.        ,  1.        ,  0.79913139, ...,  0.99609375,
#          0.90044212,  0.56125641],
#        [ 0.        ,  1.        ,  0.6904583 , ...,  0.98828125,
#          0.96848297,  0.56125641]], dtype=float32)

# %%
y
# Out:
# array([  2.12183000e+05,   4.99000000e+03,   4.98730000e+04, ...,
#          8.24800000e+03,  -1.00000000e+00,   5.29930000e+04], dtype=float32)

# %%
import math
log_f= lambda x: math.log(x+2)
# log_f= lambda x: x

y = list(map(log_f,y))

# math.log(y+2)
# y

# %% [markdown]
# Now we will split data to train/test:

# %%
from sklearn.cross_validation import train_test_split 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=92)
len(X_train), len(X_test)
# Out:
# (459294, 226220)

# %% [markdown]
# Now we are prepared. Lets check some models and see results.
#
# Algortihm benchmark
# --------

# %% [markdown]
# RandomForestRegressor
# ----------------
# First lets see how well RandomForestRegressor performs.

# %%
# Fit a Random Forest 
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

exp_2 = lambda x: math.exp(x) -2
y_test = list(map(exp_2,y_test))
y_pred = list(map(exp_2,y_pred))

output=[]
# comparing real values to predicted
for answ, pred in zip(y_test, y_pred): 
    output.append( (answ,pred) )
display(output[:100])
# Out:
# [(3406.0000000000023, 3463.0226413135697),
#  (6107.999999999997, 7456.585970674645),
#  (121975.00000000009, 86991.76748753508),
#  (2102.9999999999995, 4182.316446750734),
#  (71452.99999999996, 64343.340657492176),
#  (3286.0000000000023, 3921.1659418347413),
#  (943.9999999999998, 1841.6504806155408),
#  (2565.0, 3125.442585619142),
#  (204088.00000000015, 247506.18025090176),
#  (-1.0, -1.0),
#  (7654.000000000003, 9001.587192398389),
#  (140282.99999999994, 66018.0495403451),
#  (87693.00000000001, 120001.74143537428),
#  (25554.999999999978, 43737.49522671754),
#  (418282.00000000023, 672402.1888791535),
#  (13211.999999999993, 12657.032934420635),
#  (22015.000000000007, 6300.487485943783),
#  (-1.0, -1.0),
#  (3892.000000000003, 4202.5159825916535),
#  (-1.0, -1.0),
#  (3874.9999999999973, 4977.516449647607),
#  (-1.0, -1.0),
#  (3967.9999999999986, 3827.6835641282873),
#  (1324.0, 2290.5295595774987),
#  (10227.999999999998, 9577.51475171496),
#  (97482.99999999993, 227154.35458305592),
#  (2256268.000000001, 2094291.3388710257),
#  (3057.9999999999977, 3067.2870445864432),
#  (15178.999999999996, 21915.454045668364),
#  (167297.99999999985, 220563.77067808583),
#  (1909.0000000000002, 2054.7663196823737),
#  (3018.000000000001, 2195.101209444855),
#  (1982.999999999999, 1752.6103703451147),
#  (-1.0, -1.0),
#  (2708.000000000001, 2666.2030576807424),
#  (1598.9999999999995, 2093.8191654687753),
#  (-1.0, -1.0),
#  (7648.999999999997, 7830.869467392847),
#  (143167.99999999988, 182842.45851537012),
#  (-1.0, -1.0),
#  (123719.99999999993, 148866.047055962),
#  (14620.999999999987, 9396.547003121814),
#  (12490.0, 15023.941930306055),
#  (6039.999999999999, 4986.932050888934),
#  (4151.999999999999, 4148.8259289726675),
#  (61476.00000000002, 82177.96300371228),
#  (3626.9999999999995, 4646.646954276153),
#  (-1.0, -1.0),
#  (2229.0, 2229.345610746723),
#  (757.0000000000003, 979.0472889953816),
#  (1552.9999999999998, 3209.481794594239),
#  (16438.0, 17390.952081577303),
#  (3253.9999999999995, 1934.6394352519628),
#  (11714.0, 13456.485585791137),
#  (-1.0, -1.0),
#  (11992.999999999995, 12022.633908530921),
#  (-1.0, -1.0),
#  (-1.0, -1.0),
#  (25740.999999999996, 68417.09896465999),
#  (8006.000000000001, 6523.759723954363),
#  (66178.0, 62221.01773023797),
#  (2025.999999999999, 1980.0679915762612),
#  (7280.000000000002, 6893.894659521922),
#  (-1.0, -1.0),
#  (-1.0, -1.0),
#  (3451.9999999999995, 3416.0733162808947),
#  (1479.9999999999995, 1516.2133597556153),
#  (587.9999999999998, 547.7655672999576),
#  (8531.000000000005, 12446.094879147948),
#  (84158.99999999997, 63109.93162223499),
#  (3788.9999999999973, 3953.2551980892326),
#  (5222.000000000001, 7051.466744544846),
#  (1443.0000000000005, 1121.979587559535),
#  (-1.0, -1.0),
#  (-1.0, -1.0),
#  (52937.999999999985, 42651.42174526838),
#  (4218.000000000002, 4655.10748733623),
#  (-1.0, -1.0),
#  (1889.9999999999995, 2502.2188581541777),
#  (5819.000000000003, 7298.994348572718),
#  (10125.000000000004, 11059.827299945755),
#  (146712.00000000012, 232714.1726447325),
#  (1041.9999999999995, 1277.9018722392134),
#  (7409.999999999994, 9769.312890622123),
#  (1172096.0, 366708.65304002335),
#  (3203.999999999999, 2499.845560362388),
#  (10682.000000000005, 8380.554541897427),
#  (-1.0, -1.0),
#  (50409.00000000004, 215140.0474660412),
#  (11718.999999999993, 18047.02920658591),
#  (9595.0, 14267.226432796693),
#  (6265.000000000002, 6740.119329349954),
#  (734569.9999999994, 235647.7907756409),
#  (4117.999999999998, 4366.294769387263),
#  (41437.00000000004, 74408.14154948921),
#  (1647.9999999999998, 2102.4953100086645),
#  (123850.9999999999, 124445.25097735427),
#  (599.9999999999999, 2235.266779877269),
#  (13407.999999999989, 12841.322150346501),
#  (2347.0, 1884.0361260892616)]

# %% [markdown]
# Error rates of this model:

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error 
print('MAE: {0}'.format(mean_absolute_error(y_test,y_pred)))
print ('RMSE: {0}'.format(mean_squared_error(y_test,y_pred)))
# Out:
# MAE: 28090.9425879443
# RMSE: 19986768379.36215

# %% [markdown]
# SGD Regressor
# -------------

# %%
# from sklearn import linear_model
# model = linear_model.SGDRegressor()
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)


# output=[]
# # comparing real values to predicted
# for answ, pred in zip(y_test, y_pred): 
#     output.append( (answ,pred) )
# display(output[:100])

# %%
# print('MAE: {0}'.format(mean_absolute_error(y_test,y_pred)))
# print ('RMSE: {0}'.format(mean_squared_error(y_test,y_pred)))

# %% [markdown]
# Cearly, not very good

# %% [markdown]
# ElasticNet
# -----------

# %%
# from sklearn import linear_model
# model = linear_model.Lasso(alpha=0.5)
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)

# output=[]
# # comparing real values to predicted
# for answ, pred in zip(y_test, y_pred): 
#     output.append( (answ,pred) )
# display(output[:100])

# %%
# print('MAE: {0}'.format(mean_absolute_error(y_test,y_pred)))
# print ('RMSE: {0}'.format(mean_squared_error(y_test,y_pred)))

# %% [markdown]
# Ridge
# -----

# %%
# from sklearn import linear_model
# model = linear_model.Ridge(alpha=1.0)
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)

# output=[]
# # comparing real values to predicted
# for answ, pred in zip(y_test, y_pred): 
#     output.append( (answ,pred) )
# display(output[:100])

# %%
# print('MAE: {0}'.format(mean_absolute_error(y_test,y_pred)))
# print ('RMSE: {0}'.format(mean_squared_error(y_test,y_pred)))

# %% [markdown]
# Conclusion
# ------
# So random forest is the only ML algorithm that give predictions not so far away.

# %% [markdown]
# Resources
# -------
# - http://stackoverflow.com/questions/11023411/how-to-import-csv-data-file-into-scikit-learn
# - http://pandas.pydata.org/
# - http://scikit-learn.org/stable/modules/scaling_strategies.html
# - http://stackoverflow.com/questions/9590114/importance-of-pca-or-svd-in-machine-learning
# - http://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_error.html
# - http://scikit-learn.org/stable/modules/feature_selection.html#variance-threshold
# - http://stackoverflow.com/questions/29298973/removing-features-with-low-variance-scikit-learn
